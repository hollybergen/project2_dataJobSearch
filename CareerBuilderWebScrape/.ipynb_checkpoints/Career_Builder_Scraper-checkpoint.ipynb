# %%
# Import Dependencies

import pandas as pd
import json
from pprint import pprint
import re
import mechanize
import mechanicalsoup
import selenium
import time

browser = mechanicalsoup.StatefulBrowser()

# %% [markdown]
# # Job Count Scraper Function

# %%
def jobCount(job, city):

    try:
        url = "https://www.careerbuilder.com/insights"

        browser.open(url)
        browser.select_form("input")
        browser.select_form('form[action="https://www.careerbuilder.com/jobs"]')
        browser["keywords"] = job
        browser["location"] = city
        response = browser.submit_selected()
        soup = response.soup
        count = soup.find("div", class_="job-results").find("div", class_="count").text.replace(" Jobs", "")\
        .replace("(","").replace(")","")
        count = int(float(count))
    
        return count
    
    except:
        print(f'Error occurred for ' + job + " in " + city)
        pass

# %%
jobCount("Data Engineer", "los angeles")
# Out:
# 300

# %%
# Run through loops & run function to get count of number of each job per city

# test variables to save time

test_job = ['data engineer']
test_city = ['san diego', 'los angeles']

search_jobs = ['data scientist', 'data engineer', 'data analyst', 'statistician', 'data & analytics manager']
search_cities = ['ann arbor', 'atlanta', 'austin', 'boston', 'charlotte', 'chicago', 'cincinnati', 'columbia', 'dallas', 'denver', 'houston', 'jacksonville', 'los angeles', 'louisville', 'miami', 'minneapolis', 'nashville', 'new york', 'newport news', 'phoenix', 'san diego', 'san francisco', 'seattle', 'virginia beach']

result_dict = {}

for job in search_jobs:
    # new dictionary for city
    city_dict = {}
    
    for city in search_cities:
        # load to dictionary with city as the key
        city_dict[(f'{city}')] = jobCount(job, city) #, careerInfo(job, city)
        
    # load to dictionary with job as the key
    result_dict[(f'{job}')] = city_dict
# Out:
# Error occurred for data scientist in austin
# Error occurred for data scientist in newport news
# Error occurred for data scientist in virginia beach
# Error occurred for statistician in columbia

# %%
print(pprint(result_dict))
# Out:
# {'data & analytics manager': {'ann arbor': 21,
#                               'atlanta': 86,
#                               'austin': 39,
#                               'boston': 61,
#                               'charlotte': 42,
#                               'chicago': 119,
#                               'cincinnati': 15,
#                               'columbia': 3,
#                               'dallas': 84,
#                               'denver': 28,
#                               'houston': 41,
#                               'jacksonville': 11,
#                               'los angeles': 97,
#                               'louisville': 6,
#                               'miami': 23,
#                               'minneapolis': 19,
#                               'nashville': 13,
#                               'new york': 160,
#                               'newport news': 13,
#                               'phoenix': 32,
# ...

# %%
# Turn dictionary into JSON file
with open('job_counts.json', 'w') as fp:
    json.dump(result_dict, fp)

# %%
jobCount("Data Engineer", "los angeles")
# Out:
# Error occurred for Data Engineer in los angeles

# %%
def careerInfo(job, city):

    try:

# %%
url = "https://www.careerbuilder.com/salary"

browser.open(url)
browser.select_form("input")
browser.select_form('form[action="/salary"]')
        
browser["salary_title"] = "data scientist"
browser["salary_location"] = "los angeles"

browser.

# %%
response = browser.submit_selected()

# %%
soup = response.soup   

#class_="row salary-info"
salary = soup.find("div", class_="main-body").find("div", class_="salary-search").find_all("article")[2]

# doc.click()
# time.sleep(5)


print(pprint(salary))
# Out:
# <article class="small-12 medium-2 columns search-form-column">
# <input class="salary-search-submit btn" disabled="disabled" type="submit" value="Search"/>
# </article>
# None

# %%
        browser["keywords"] = job
        browser["location"] = city
        response = browser.submit_selected()
        soup = response.soup
        count = soup.find("div", class_="job-results").find("div", class_="count").text
        return count
    
    except:
        print(f'Error occurred for ' + job + " in " + city)
        pass

# %%
# test variables to save time

test_job = ['data engineer']
test_city = ['san diego', 'los angeles']

search_jobs = ['data scientist', 'data engineer', 'data analyst', 'statistician', 'data & analytics manager']
search_cities = ['ann arbor', 'atlanta', 'austin', 'boston', 'charlotte', 'chicago', 'cincinnati', 'columbia', 'dallas', 'denver', 'houston', 'jacksonville', 'los angeles', 'louisville', 'miami', 'minneapolis', 'nashville', 'new york', 'newport news', 'phoenix', 'san diego', 'san francisco', 'seattle', 'virginia beach']

result_dict = {}

for job in test_job:
    # new dictionary for city
    city_dict = {}
    
    for city in test_city:
        # load to dictionary with city as the key
        city_dict[(f'{city}')] = jobCount(job, city) #, careerInfo(job, city)
        
    # load to dictionary with job as the key
    result_dict[(f'{job}')] = city_dict

# %%
url = "https://www.careerbuilder.com/insights"

browser.open(url)
browser.select_form("input")
browser.select_form('form[action="https://www.careerbuilder.com/jobs"]')

browser["keywords"] = "data engineer"
browser["location"] = "san diego"

response = browser.submit_selected()
soup = response.soup
count = soup.find("div", class_="job-results").find("div", class_="count").text

print(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-30c2752caacc> in <module>()
#       1 url = "https://www.careerbuilder.com/insights"
#       2
# ----> 3 browser.open(url)
#       4 browser.select_form("input")
#       5 browser.select_form('form[action="https://www.careerbuilder.com/jobs"]')
#
# NameError: name 'browser' is not defined

# %%
parse("data engineer", "san diego")
# Out:
# '(236 Jobs)'

# %%
browser.launch_browser()

# %%
browser.get_url()
# Out:
# 'https://www.careerbuilder.com/insights'

# %%
br = mechanize.Browser()
br.set_handle_robots(False)
br.set_handle_equiv(False) 
br.open("https://www.linkedin.com/salary/")
# Out:
# <response_seek_wrapper at 0x5667eb8 whose wrapped object = <closeable_response at 0x5667e80 whose fp = <_io.BufferedReader name=1236>>>

# %%
import mechanicalsoup
browser = mechanicalsoup.StatefulBrowser()

# %%
browser.open("https://www.linkedin.com/salary/")
# Out:
# <Response [200]>

# %%
browser.get_url()
# Out:
# 'https://www.linkedin.com/salary/'

# %%
browser.get_current_page().find_all('div')
# Out:
# [<div aria-live="polite" class="visually-hidden" id="live-region"></div>]

# %%
browser.select_form(name="input")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-d6c1d1947343> in <module>()
# ----> 1 browser.select_form(name="input")
#
# TypeError: select_form() got an unexpected keyword argument 'name'

# %%
browser.get_current_page()
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# ...

# %%
browser.get_current_form().print_summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-cf464b3564b4> in <module>()
# ----> 1 browser.get_current_form().print_summary()
#
# AttributeError: 'NoneType' object has no attribute 'print_summary'

# %%
br.forms
# Out:
# <bound method Browser.forms of <mechanize._mechanize.Browser object at 0x0000000005676E48>>

# %%
br.select_form
# Out:
# <bound method Browser.select_form of <mechanize._mechanize.Browser object at 0x0000000005676E48>>

# %%
br.get_current_form().print_summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-6e631b8230e7> in <module>()
# ----> 1 br.get_current_form().print_summary()
#
# ~\Anaconda3\lib\site-packages\mechanize\_mechanize.py in __getattr__(self, name)
#     783             raise AttributeError(
#     784                 "%s instance has no attribute %s (perhaps you forgot to "
# --> 785                 ".select_form()?)" % (self.__class__, name))
#     786         return getattr(form, name)
#     787
#
# AttributeError: <class 'mechanize._mechanize.Browser'> instance has no attribute get_current_form (perhaps you forgot to .select_form()?)

# %%
# follow second link with element text matching regular expression
response1 = br.follow_link(text_regex=r"cheese\s*shop", nr=1)
print(br.title())
print(response1.geturl())
print(response1.info())  # headers
print(response1.read())  # body
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\mechanize\_mechanize.py in find_link(self, text, text_regex, name, name_regex, url, url_regex, tag, predicate, nr)
#     774                 self._factory.links(), text, text_regex, name, name_regex, url,
# --> 775                 url_regex, tag, predicate, nr))
#     776         except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# LinkNotFoundError                         Traceback (most recent call last)
# <ipython-input-62-67bc89e91e4c> in <module>()
#       1 # follow second link with element text matching regular expression
# ----> 2 response1 = br.follow_link(text_regex=r"cheese\s*shop", nr=1)
#       3 print(br.title())
#       4 print(response1.geturl())
#       5 print(response1.info())  # headers
#
# ...

# %%
br.select_form(name="order")
# Browser passes through unknown attributes (including methods)
# to the selected HTMLForm.
br["cheeses"] = ["mozzarella", "caerphilly"]  # (the method here is __setitem__)
# Submit current form.  Browser calls .close() on the current response on
# navigation, so this closes response1
response2 = br.submit()

# print currently selected form (don't call .submit() on this, use br.submit())
print(br.form)

response3 = br.back()  # back to cheese shop (same data as response1)
# the history mechanism returns cached response objects
# we can still use the response, even though it was .close()d
response3.get_data()  # like .seek(0) followed by .read()
response4 = br.reload()  # fetches from server

for form in br.forms():
    print(form)
# .links() optionally accepts the keyword args of .follow_/.find_link()
for link in br.links(url_regex="python.org"):
    print(link)
    br.follow_link(link)  # takes EITHER Link instance OR keyword args
    br.back()

# %%
path = "glassdoor_data.json"

# %%
with open(path) as f:
    data = json.load(f)

pprint(data)
# Out:
# {'data analyst': {'ann arbor': [{'City': 'Ann Arbor',
#                                  'Company': '',
#                                  'Location': 'Ann Arbor, MI',
#                                  'Name': 'Analyst-Data Quality',
#                                  'Salary': '',
#                                  'State': 'MI',
#                                  'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=359453&s=149&guid=0000016ae712d97c9e45836a3bae0424&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_46c4957a&cb=1558654934163&jobListingId=3194439341'},
#                                 {'City': 'Ann Arbor',
#                                  'Company': '',
#                                  'Location': 'Ann Arbor, MI',
#                                  'Name': 'Data Analyst',
#                                  'Salary': '',
#                                  'State': 'MI',
# ...

# %%
ds_aa = data['data scientist']['ann arbor']

count = []

for item in ds_aa:
    count.append(item)
    
len(count)
# Out:
# 30

# %%
ds_sd = data['data scientist']['san diego']

count = []

for item in ds_sd:
    count.append(item)

len(count)
# Out:
# 30
