# %%
from lxml import html, etree
import argparse
import json
import os
import requests
import re
import sys
import time
import unicodecsv as csv

def parse(keyword, place):

    headers = {	'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
                'accept-encoding': 'gzip, deflate, sdch, br',
                'accept-language': 'en-GB,en-US;q=0.8,en;q=0.6',
                'referer': 'https://www.glassdoor.com/',
                'upgrade-insecure-requests': '1',
                'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/51.0.2704.79 Chrome/51.0.2704.79 Safari/537.36',
                'Cache-Control': 'no-cache',
                'Connection': 'keep-alive'
        }

    location_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.01',
        'accept-encoding': 'gzip, deflate, sdch, br',
        'accept-language': 'en-GB,en-US;q=0.8,en;q=0.6',
        'referer': 'https://www.glassdoor.com/',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/51.0.2704.79 Chrome/51.0.2704.79 Safari/537.36',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive'
    }
    data = {"term": place, "maxLocationsToReturn": 20}

    location_url = "https://www.glassdoor.co.in/findPopularLocationAjax.htm?"
    try:
        time.sleep(7)

        # Getting location id for search location
        print("Fetching location details")
        location_response = requests.post(location_url, headers=location_headers, data=data).json()
        place_id = location_response[0]['locationId']
        job_litsting_url = 'https://www.glassdoor.com/Job/jobs.htm'
        # Form data to get job results
        data = {
            'clickSource': 'searchBtn',
            'sc.keyword': keyword,
            'locT': 'C',
            'locId': place_id,
            'jobType': ''
        }

        job_listings = []
        if place_id:
            response = requests.post(job_litsting_url, headers=headers, data=data)
            # extracting data from
            # https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=true&clickSource=searchBtn&typedKeyword=andr&sc.keyword=android+developer&locT=C&locId=1146821&jobType=
            parser = html.fromstring(response.text)
            # Making absolute url 
            base_url = "https://www.glassdoor.com"
            parser.make_links_absolute(base_url)

            XPATH_ALL_JOB = '//li[@class="jl"]'
            XPATH_NAME = './/a/text()'
            XPATH_JOB_URL = './/a/@href'
            XPATH_LOC = './/span[@class="subtle loc"]/text()'
            XPATH_COMPANY = './/div[@class="flexbox empLoc"]/div/text()'
            XPATH_SALARY = './/span[@class="green small"]/text()'

            listings = parser.xpath(XPATH_ALL_JOB)
            for job in listings:
                raw_job_name = job.xpath(XPATH_NAME)
                raw_job_url = job.xpath(XPATH_JOB_URL)
                raw_lob_loc = job.xpath(XPATH_LOC)
                raw_company = job.xpath(XPATH_COMPANY)
                raw_salary = job.xpath(XPATH_SALARY)

                # Cleaning data
                job_name = ''.join(raw_job_name).strip('–') if raw_job_name else None
                job_location = ''.join(raw_lob_loc) if raw_lob_loc else None
                raw_state = re.findall(",\s?(.*)\s?", job_location)
                state = ''.join(raw_state).strip()
                raw_city = job_location.replace(state, '')
                city = raw_city.replace(',', '').strip()
                company = ''.join(raw_company).replace('–','')
                salary = ''.join(raw_salary).strip()
                job_url = raw_job_url[0] if raw_job_url else None

                jobs = {
                    "Name": job_name,
                    "Company": company,
                    "State": state,
                    "City": city,
                    "Salary": salary,
                    "Location": job_location,
                    "Url": job_url
                }
                job_listings.append(jobs)
            return job_listings
        else:
            print("location id not available")

    except:
        print("Failed to load locations")

    if __name__ == "__main__":

#     ''' eg-:python 1934_glassdoor.py "Android developer", "new york" '''

        argparser = argparse.ArgumentParser()
        argparser.add_argument('keyword', help='job name', type=str)
        argparser.add_argument('place', help='job location', type=str)
        args = argparser.parse_args()
        keyword = args.keyword
        place = args.place
        print("Fetching job details")
        scraped_data = parse(keyword, place)
        print("Writing data to output file")

        with open('%s-%s-job-results.csv' % (keyword, place), 'wb')as csvfile:
            fieldnames = ['Name', 'Company', 'State',
                          'City', 'Salary', 'Location', 'Url']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames,quoting=csv.QUOTE_ALL)
            writer.writeheader()
            if scraped_data:
                for data in scraped_data:
                    writer.writerow(data)
            else:
                print("Your search for %s, in %s does not match any jobs"%(keyword,place))

# %%
# test variables to save time
search_job = ['data scientist', 'data engineer']
search_city = ['san diego', 'los angeles']

# search_job = ['data scientist', 'data engineer', 'data analyst']
# search_city = ['san diego', 'los angeles', 'san francisco', 'denver', 'austin', 'new york']
result_dict = {}

for job in search_job:
    # new dictionary for city
    city_dict = {}
    
    for city in search_city:
        # load to dictionary with city as the key
        city_dict[(f'{city}')] = parse(job, city)
        
    # load to dictionary with job as the key
    result_dict[(f'{job}')] = city_dict
# Out:
# Fetching location details
# Fetching location details
# Fetching location details
# Fetching location details

# %%
len(result_dict)
# Out:
# 2

# %%
result_dict.keys()
# Out:
# dict_keys(['data scientist', 'data engineer'])

# %%
result_dict
# Out:
# {'data scientist': {'san diego': [{'Name': 'Data Scientist',
#     'Company': ' Dexcom  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$95k-$134k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=296910&s=149&guid=0000016ad69398078266b94020925512&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cba900ae&cb=1558378158749&jobListingId=3129909498'},
#    {'Name': 'Senior Data Scientist',
#     'Company': ' Tealium  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$143k-$191k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=642403&s=149&guid=0000016ad69398078266b94020925512&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8f67c27b&cb=1558378158751&jobListingId=3232692044'},
#    {'Name': 'Machine Learning Engineer - Data Analysis',
#     'Company': ' Samsung Semiconductor, Inc.  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$99k-$134k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=630701&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a8746cc1&cb=1558378158752&jobListingId=3223997059'},
#    {'Name': 'Data Engineer',
#     'Company': ' LeadCrunch  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$125k-$155k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=535387&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_81cb9612&cb=1558378158753&jobListingId=2996249774'},
#    {'Name': 'Scientist I',
#     'Company': ' Takeda Pharmaceuticals  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$88k-$121k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=488112&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e47998bd&cb=1558378158754&jobListingId=3233298933'},
#    {'Name': 'Data Scientist',
#     'Company': ' Indeed Prime  New',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=437638&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2ea6999b&cb=1558378158755&jobListingId=3042963556'},
#    {'Name': 'Data Analyst',
#     'Company': ' Mindstream Media  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$40k-$63k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=535423&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_703aae88&cb=1558378158756&jobListingId=3103048891'},
#    {'Name': 'Data Scientist (Machine Learning)',
#     'Company': ' Experian  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$101k-$137k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=610985&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9ca1bcb5&cb=1558378158757&jobListingId=3232187804'},
#    {'Name': 'Staff Scientist',
#     'Company': ' Illumina  Top Company',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7980c219&cb=1558378158799&jobListingId=3125952519'},
#    {'Name': 'Senior Scientist',
#     'Company': ' Illumina  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$104k-$140k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_655a22c4&cb=1558378158810&jobListingId=3158761344'},
#    {'Name': '#99510 (CLS) Clinical Lab Scientist Specialist',
#     'Company': ' UC San Diego  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$32-$45\xa0per hour',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=4120&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_44a6a3f8&cb=1558378158811&jobListingId=3235492301'},
#    {'Name': 'Staff Data Scientist',
#     'Company': ' National Funding  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$121k-$171k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=541807&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_16230220&cb=1558378158813&jobListingId=3122353252'},
#    {'Name': 'Principal Scientist',
#     'Company': ' Takeda Pharmaceuticals  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$121k-$162k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=488112&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_081a1578&cb=1558378158814&jobListingId=3189007535'},
#    {'Name': 'Scientist 1',
#     'Company': ' Illumina  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$72k-$96k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3cbd8eca&cb=1558378158815&jobListingId=3107155666'},
#    {'Name': 'Principal Scientist, Biomarkers and Companion Diagnostics',
#     'Company': ' Rakuten Medical  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=78823&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2e1819eb&cb=1558378158816&jobListingId=3234939918'},
#    {'Name': 'Bioinformatics Scientist',
#     'Company': ' Illumina  Top Company',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_21ac0118&cb=1558378158818&jobListingId=3198811559'},
#    {'Name': 'Senior Data Scientist',
#     'Company': ' ICW Group  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$122k-$164k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=523741&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2d194bd4&cb=1558378158818&jobListingId=3188967021'},
#    {'Name': 'Data Analyst',
#     'Company': ' Encore Capital Group  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$49k-$76k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=413637&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2340851b&cb=1558378158820&jobListingId=3216549600'},
#    {'Name': 'Software Engineer (Data Analysis)',
#     'Company': ' ASML  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$82k-$139k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=580354&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_dd8ee489&cb=1558378158821&jobListingId=3199423402'},
#    {'Name': 'Data Scientist',
#     'Company': ' Broadcom  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$114k-$154k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=242900&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b1768118&cb=1558378158822&jobListingId=3076652924'},
#    {'Name': 'DATA SCIENTIST - ACO',
#     'Company': ' Scripps Health  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$90k-$122k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=182759&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3be8dc0d&cb=1558378158824&jobListingId=3229941259'},
#    {'Name': 'Data Scientist - Analytics and Cognitive (Government)',
#     'Company': ' Deloitte  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$116k-$160k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=144580&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_14cc83ed&cb=1558378158825&jobListingId=3152099627'},
#    {'Name': 'Computer Scientist',
#     'Company': ' SPAWAR Systems Center Pacific  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$65k-$125k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=544406&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_6883e82d&cb=1558378158826&jobListingId=3133341553'},
#    {'Name': 'Data Scientist',
#     'Company': ' Amazon  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$115k-$157k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=133043&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c4b85a53&cb=1558378158827&jobListingId=3090515165'},
#    {'Name': 'Associate Scientist II - Immunology',
#     'Company': ' Johnson & Johnson  Top Company',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=321738&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cd7068bd&cb=1558378158828&jobListingId=3236109516'},
#    {'Name': 'Data Scientist Intern',
#     'Company': ' Housecall Pro  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=215203&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5f8c29f7&cb=1558378158829&jobListingId=3226356078'},
#    {'Name': 'Data Scientist / Deep Learning Engineer',
#     'Company': ' Intel  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$100k-$136k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=132930&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b62c1ab9&cb=1558378158830&jobListingId=3180980559'},
#    {'Name': 'Data Scientist',
#     'Company': ' Booz Allen Hamilton Inc.  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$93k-$139k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=134088&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7b4c075d&cb=1558378158831&jobListingId=3025037807'},
#    {'Name': 'Data Scientist Intern',
#     'Company': ' Experian  ',
#     'State': 'CA',
#     'City': 'El Cajon',
#     'Salary': '',
#     'Location': 'El Cajon, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=200539&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c50f194e&cb=1558378158832&jobListingId=3232186494'},
#    {'Name': 'Data Science Intern',
#     'Company': ' Cuker  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=4120&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7ea2767d&cb=1558378158833&jobListingId=3173130340'}],
#   'los angeles': [{'Name': 'Data Scientist Senior',
#     'Company': ' Capital Group  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$115k-$155k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=360325&s=149&guid=0000016ad693b93da338f235b017c77e&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5bd46239&cb=1558378167211&jobListingId=3136656764'},
#    {'Name': 'Data Scientist',
#     'Company': ' Thrive Market  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$106k-$146k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=556693&s=149&guid=0000016ad693b93da338f235b017c77e&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cfe87e4d&cb=1558378167213&jobListingId=3221727527'},
#    {'Name': 'Data Scientist',
#     'Company': ' Rubicon Project  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$116k-$157k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=601125&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c2175a97&cb=1558378167214&jobListingId=3123198897'},
#    {'Name': 'Data Scientist',
#     'Company': ' Indeed Prime  New',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=437627&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7c764e02&cb=1558378167215&jobListingId=3042963551'},
#    {'Name': 'Data Engineer',
#     'Company': ' Capital Group  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$110k-$148k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=211228&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_02f19599&cb=1558378167216&jobListingId=3216658621'},
#    {'Name': 'Data Scientist, Machine Learning',
#     'Company': ' ZestFinance  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$105k-$142k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=498820&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_876f08b1&cb=1558378167217&jobListingId=3018182751'},
#    {'Name': 'Data Scientist - New Grad',
#     'Company': ' Beyond Limits  ',
#     'State': 'CA',
#     'City': 'Glendale',
#     'Salary': '$128k-$185k',
#     'Location': 'Glendale, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=4128&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_42d389cb&cb=1558378167219&jobListingId=3008596745'},
#    {'Name': 'Data Scientist',
#     'Company': " Jobot  We're Hiring",
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=594271&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8ffb5d1e&cb=1558378167220&jobListingId=3226583477'},
#    {'Name': 'Data Scientist - Platform',
#     'Company': ' Inspire  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$82k-$115k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=570001&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_181f2066&cb=1558378167222&jobListingId=3191351179'},
#    {'Name': 'Data Scientist, Product Analytics',
#     'Company': ' BuzzFeed  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$110k-$154k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=4120&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_1505cdf0&cb=1558378167223&jobListingId=3231063575'},
#    {'Name': 'Data Scientist',
#     'Company': ' Walt Disney Company  ',
#     'State': 'CA',
#     'City': 'Burbank',
#     'Salary': '$112k-$153k',
#     'Location': 'Burbank, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=191997&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3f1827dc&cb=1558378167225&jobListingId=3233583443'},
#    {'Name': 'Associate Data Scientist',
#     'Company': ' Sense360  Hot',
#     'State': 'CA',
#     'City': 'Culver City',
#     'Salary': '',
#     'Location': 'Culver City, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=215203&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_18896142&cb=1558378167226&jobListingId=3159337730'},
#    {'Name': 'Junior Data Scientist',
#     'Company': ' Ranker  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$91k-$133k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=7438&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_89400fb1&cb=1558378167227&jobListingId=3187767725'},
#    {'Name': 'Data Scientist',
#     'Company': ' Roku  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '$149k-$199k',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=136412&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_b60ecc52&cb=1558378167228&jobListingId=3183454466'},
#    {'Name': 'Data Scientist',
#     'Company': ' Schlumberger  ',
#     'State': 'CA',
#     'City': 'Pasadena',
#     'Salary': '$99k-$142k',
#     'Location': 'Pasadena, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=400784&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2044bfd1&cb=1558378167230&jobListingId=3137356443'},
#    {'Name': 'Sr Data Scientist',
#     'Company': ' Neustar  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$110k-$148k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=610217&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7591936a&cb=1558378167232&jobListingId=3190366941'},
#    {'Name': 'Data Scientist',
#     'Company': ' Genuent  ',
#     'State': 'CA',
#     'City': 'Burbank',
#     'Salary': '$105k-$145k',
#     'Location': 'Burbank, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=83255&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_84f66d67&cb=1558378167233&jobListingId=3214605433'},
#    {'Name': 'Data Scientist Organizational Performance',
#     'Company': ' Southern California Edison  ',
#     'State': 'CA',
#     'City': 'Rosemead',
#     'Salary': '$108k-$149k',
#     'Location': 'Rosemead, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=398947&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a2f1c5cb&cb=1558378167234&jobListingId=3156833700'},
#    {'Name': 'Senior Data Scientist',
#     'Company': ' Headspace  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '$139k-$188k',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=524781&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_03e2ff3c&cb=1558378167235&jobListingId=3067455252'},
#    {'Name': 'Data Scientist',
#     'Company': ' Sony Pictures Entertainment  ',
#     'State': 'CA',
#     'City': 'Culver City',
#     'Salary': '$117k-$164k',
#     'Location': 'Culver City, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=242900&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2d5f77a5&cb=1558378167236&jobListingId=3183128471'},
#    {'Name': 'Data Scientist',
#     'Company': ' Unilever  ',
#     'State': 'CA',
#     'City': 'Marina del Rey',
#     'Salary': '$92k-$128k',
#     'Location': 'Marina del Rey, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=400784&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_aed51eb1&cb=1558378167238&jobListingId=3189602874'},
#    {'Name': 'Data Scientist ( Risk / Quantitative )',
#     'Company': ' Ascent  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$83k-$124k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=157444&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_24ef970d&cb=1558378167239&jobListingId=3222084662'},
#    {'Name': 'Junior Data Scientist',
#     'Company': ' Fama (CA)  ',
#     'State': 'CA',
#     'City': 'Playa Vista',
#     'Salary': '',
#     'Location': 'Playa Vista, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=4120&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cd7fd631&cb=1558378167240&jobListingId=2905612987'},
#    {'Name': 'Data Scientist',
#     'Company': ' Aspiration  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$97k-$131k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=148364&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_755696d1&cb=1558378167242&jobListingId=3211087380'},
#    {'Name': 'Data Scientist, Advertising',
#     'Company': ' Los Angeles Times  ',
#     'State': 'CA',
#     'City': 'El Segundo',
#     'Salary': '$116k-$159k',
#     'Location': 'El Segundo, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=242900&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f9000f5c&cb=1558378167243&jobListingId=3180202701'},
#    {'Name': 'Data Scientist',
#     'Company': ' Dollar Shave Club  ',
#     'State': 'CA',
#     'City': 'Marina del Rey',
#     'Salary': '$104k-$144k',
#     'Location': 'Marina del Rey, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=136357&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_14716143&cb=1558378167245&jobListingId=3187588596'},
#    {'Name': 'Data Scientist - League of Legends',
#     'Company': ' Riot Games  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$113k-$151k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=133118&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_6092edfe&cb=1558378167247&jobListingId=3203719223'},
#    {'Name': 'Data Scientist',
#     'Company': ' Allrecipes.com  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$90k-$123k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=352789&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_846eea1d&cb=1558378167249&jobListingId=3124885861'},
#    {'Name': 'Data Scientist',
#     'Company': ' Aquent  ',
#     'State': 'CA',
#     'City': 'El Segundo',
#     'Salary': '',
#     'Location': 'El Segundo, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=636746&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7003a458&cb=1558378167250&jobListingId=3232254253'},
#    {'Name': 'Data Scientist',
#     'Company': ' Amazon  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '$115k-$158k',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=133043&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9dd9c64f&cb=1558378167251&jobListingId=3234591396'}]},
#  'data engineer': {'san diego': [{'Name': 'Data Engineer',
#     'Company': ' LeadCrunch  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$125k-$155k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=535387&s=149&guid=0000016ad693d9d09ad14d33216866a9&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_268dba92&cb=1558378175734&jobListingId=2996249774'},
#    {'Name': 'Machine Learning Engineer - Data Analysis',
#     'Company': ' Samsung Semiconductor, Inc.  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$99k-$134k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=630701&s=149&guid=0000016ad693d9d09ad14d33216866a9&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0f324041&cb=1558378175736&jobListingId=3223997059'},
#    {'Name': 'Front End Engineer',
#     'Company': ' foresee medical, inc.  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=526615&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7d575d07&cb=1558378175737&jobListingId=2613473725'},
#    {'Name': 'Data Analyst',
#     'Company': ' Mindstream Media  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$40k-$63k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=535423&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_208b4cd4&cb=1558378175738&jobListingId=3103048891'},
#    {'Name': 'Software Engineer',
#     'Company': ' Cognetic Technologies  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$50-$55\xa0per hour',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=539628&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_1388c79c&cb=1558378175739&jobListingId=3132166147'},
#    {'Name': 'Data Engineer',
#     'Company': ' Indeed Prime  New',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=437638&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c6d177be&cb=1558378175740&jobListingId=3042963969'},
#    {'Name': 'Software Engineer',
#     'Company': ' Illumina  Top Company',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=484655&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cae9bdf3&cb=1558378175741&jobListingId=3141416821'},
#    {'Name': 'Test Engineer - Navy UUV',
#     'Company': ' Peraton  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$69k-$95k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=347162&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9072d161&cb=1558378175742&jobListingId=3235848644'},
#    {'Name': 'Data Analyst',
#     'Company': ' Encore Capital Group  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$49k-$76k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=413637&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3d52ab7e&cb=1558378175743&jobListingId=3216549600'},
#    {'Name': 'Senior Data Engineer',
#     'Company': ' Dexcom  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$93k-$121k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=296869&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_90c0f452&cb=1558378175744&jobListingId=3115453635'},
#    {'Name': 'Software Test Engineer',
#     'Company': ' TrellisWare Technologies, Inc  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$76k-$109k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=514670&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_f0da3c33&cb=1558378175745&jobListingId=3234916061'},
#    {'Name': 'Senior Data Scientist',
#     'Company': ' Tealium  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$143k-$191k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=642403&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_125bf25e&cb=1558378175746&jobListingId=3232692044'},
#    {'Name': 'Data Scientist (Machine Learning)',
#     'Company': ' Experian  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$101k-$137k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=610985&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b217e569&cb=1558378175747&jobListingId=3232187804'},
#    {'Name': 'Data Scientist',
#     'Company': ' Dexcom  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$95k-$134k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=296910&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_00e447ee&cb=1558378175748&jobListingId=3129909498'},
#    {'Name': 'NLP Engineer',
#     'Company': ' foresee medical, inc.  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=526614&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ead041cf&cb=1558378175750&jobListingId=2621215401'},
#    {'Name': 'Software Engineer I',
#     'Company': ' MINDBODY, Inc  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$84k-$142k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=501515&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c23b06ed&cb=1558378175751&jobListingId=3195161977'},
#    {'Name': 'Intern, Data Insights',
#     'Company': ' Coupa Software, Inc.  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=297524&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b5d0f7c5&cb=1558378175752&jobListingId=3120295127'},
#    {'Name': 'Software Engineer , IoS',
#     'Company': ' GoPro  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$79k-$132k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=586197&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_35b2684d&cb=1558378175753&jobListingId=3162452015'},
#    {'Name': 'Backend Engineer (SD)',
#     'Company': ' Health IQ  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$90k-$115k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=599151&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_00cb4f51&cb=1558378175754&jobListingId=2881641770'},
#    {'Name': 'Software Engineer',
#     'Company': ' Electric Cryotherapy  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=582952&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_7f88479f&cb=1558378175755&jobListingId=3115832877'},
#    {'Name': 'Data Architect',
#     'Company': ' ICW Group  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$102k-$145k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=523745&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_dda0d541&cb=1558378175756&jobListingId=3118871624'},
#    {'Name': 'Data Engineer',
#     'Company': ' ClosingCorp  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$79k-$108k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=8095&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_bc702e16&cb=1558378175757&jobListingId=3080913324'},
#    {'Name': 'Data Engineer',
#     'Company': ' Illumina  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$87k-$117k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=133652&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a568a643&cb=1558378175759&jobListingId=3203897143'},
#    {'Name': 'Software Engineer (Data Analysis)',
#     'Company': ' ASML  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$82k-$139k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=580354&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8d3f06d5&cb=1558378175760&jobListingId=3199423402'},
#    {'Name': 'Data Engineer',
#     'Company': ' TEKsystems, Inc  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=320811&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0e5ba476&cb=1558378175761&jobListingId=3235690817'},
#    {'Name': 'Data Scientist',
#     'Company': ' Amazon  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$115k-$157k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=133043&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7f70c8b0&cb=1558378175762&jobListingId=3090515165'},
#    {'Name': 'Systems Engineer',
#     'Company': ' Dimension Data  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=251292&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_49de3bcb&cb=1558378175763&jobListingId=2828058683'},
#    {'Name': 'Data Scientist Intern',
#     'Company': ' Experian  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=200539&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_276b0446&cb=1558378175764&jobListingId=3232184149'},
#    {'Name': 'Systems Verification Test Engineer',
#     'Company': ' ATX Networks  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=534048&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_df84b41f&cb=1558378175765&jobListingId=2784104970'},
#    {'Name': 'Data Engineer',
#     'Company': ' Petco  ',
#     'State': 'CA',
#     'City': 'San Diego',
#     'Salary': '$76k-$103k',
#     'Location': 'San Diego, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=182759&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_104f2d00&cb=1558378175766&jobListingId=3224426668'}],
#   'los angeles': [{'Name': 'Data Engineer',
#     'Company': ' Capital Group  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$110k-$148k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=211228&s=149&guid=0000016ad693fb43a8096f7d269d5c09&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9245cba8&cb=1558378184543&jobListingId=3189368593'},
#    {'Name': 'Data Engineer, Insights & EDW',
#     'Company': ' Spokeo  ',
#     'State': 'CA',
#     'City': 'Pasadena',
#     'Salary': '$85k-$118k',
#     'Location': 'Pasadena, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=500053&s=149&guid=0000016ad693fb43a8096f7d269d5c09&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_aeaa0260&cb=1558378184545&jobListingId=3224176910'},
#    {'Name': 'Data Engineer',
#     'Company': ' Tala  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '$104k-$141k',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=553313&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_bba99808&cb=1558378184546&jobListingId=2632344894'},
#    {'Name': 'Data Engineer',
#     'Company': ' Thrive Market  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$117k-$154k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=579989&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_6f3fc96a&cb=1558378184547&jobListingId=3155903429'},
#    {'Name': 'Data Engineer',
#     'Company': ' Tradesy  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '$85k-$117k',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=544504&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_15f6c0c5&cb=1558378184548&jobListingId=2855392552'},
#    {'Name': 'Software Engineer, New Grad',
#     'Company': ' Factual  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$104k-$172k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=518741&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e9389f36&cb=1558378184549&jobListingId=2915373494'},
#    {'Name': 'Data Scientist',
#     'Company': ' Thrive Market  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$106k-$146k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=556693&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f058085f&cb=1558378184550&jobListingId=3221727527'},
#    {'Name': 'Data Engineer',
#     'Company': ' Jobot  Hot',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=549588&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9beeee14&cb=1558378184552&jobListingId=3226583474'},
#    {'Name': 'Data Engineer',
#     'Company': ' Indeed Prime  New',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=437627&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0a140c33&cb=1558378184552&jobListingId=3042963961'},
#    {'Name': 'Data Engineer',
#     'Company': ' Warner Bros.  ',
#     'State': 'CA',
#     'City': 'Burbank',
#     'Salary': '$97k-$133k',
#     'Location': 'Burbank, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=178979&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_52c9d711&cb=1558378184553&jobListingId=3025988345'},
#    {'Name': 'Data Engineer',
#     'Company': ' ZestFinance  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$132k-$174k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=498821&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_86e76342&cb=1558378184554&jobListingId=3018182760'},
#    {'Name': 'Data Scientist',
#     'Company': ' Rubicon Project  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$116k-$157k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=601125&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_6d54368f&cb=1558378184555&jobListingId=3123198897'},
#    {'Name': 'Software Engineer - Backend',
#     'Company': ' AppOnboard  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=541727&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_011ad395&cb=1558378184556&jobListingId=3077039870'},
#    {'Name': 'Entry Level Big Data Engineer',
#     'Company': ' AT&T  ',
#     'State': 'CA',
#     'City': 'El Segundo',
#     'Salary': '$85k-$118k',
#     'Location': 'El Segundo, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=132934&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f9826a0c&cb=1558378184557&jobListingId=3081339901'},
#    {'Name': 'Software Engineer (Mobile) - Los Angeles',
#     'Company': ' Opendoor  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$119k-$196k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=641193&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_234aba09&cb=1558378184558&jobListingId=3066336766'},
#    {'Name': 'Data Engineer',
#     'Company': ' Red Bull  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '$87k-$120k',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=4120&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fea3d0a3&cb=1558378184560&jobListingId=3087172195'},
#    {'Name': 'Data Engineer',
#     'Company': ' Fair  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=160631&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_1dec79b9&cb=1558378184562&jobListingId=3214163096'},
#    {'Name': 'Data Engineer (Python/SQL)',
#     'Company': ' Prosum  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$103k-$140k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=454823&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_eb86380a&cb=1558378184563&jobListingId=3214494155'},
#    {'Name': 'Data & Business Analyst',
#     'Company': ' Atom Tickets  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=582704&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_acc69c0e&cb=1558378184564&jobListingId=3172788155'},
#    {'Name': 'Software Engineer',
#     'Company': ' RepairSmith  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=546282&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_34f97d24&cb=1558378184565&jobListingId=3027706154'},
#    {'Name': 'Database Administrator',
#     'Company': ' Hallmark Labs  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '$74k-$121k',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=505851&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f957bb29&cb=1558378184566&jobListingId=2976499067'},
#    {'Name': 'Software Engineer-190189',
#     'Company': ' Ellie Mae  ',
#     'State': 'CA',
#     'City': 'El Segundo',
#     'Salary': '$78k-$133k',
#     'Location': 'El Segundo, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=401902&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_1278d118&cb=1558378184568&jobListingId=3188750224'},
#    {'Name': 'Data Engineer',
#     'Company': ' Aspiration  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$113k-$153k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=160631&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_55c9c0f6&cb=1558378184569&jobListingId=3095727688'},
#    {'Name': 'Data Science Intern',
#     'Company': ' Flo Technologies  ',
#     'State': 'CA',
#     'City': 'Culver City',
#     'Salary': '',
#     'Location': 'Culver City, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=215203&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5472a4c1&cb=1558378184570&jobListingId=3197418823'},
#    {'Name': 'Data Archive Engineer',
#     'Company': ' Giant Magellan Telescope Organization  ',
#     'State': 'CA',
#     'City': 'Pasadena',
#     'Salary': '',
#     'Location': 'Pasadena, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=582396&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_d8e8408b&cb=1558378184571&jobListingId=2766150108'},
#    {'Name': 'Data Engineer',
#     'Company': ' Sense360  ',
#     'State': 'CA',
#     'City': 'Culver City',
#     'Salary': '',
#     'Location': 'Culver City, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=215203&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_780b1236&cb=1558378184573&jobListingId=3188901633'},
#    {'Name': 'Data Engineer Analyst',
#     'Company': ' Centerfield Media  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '$96k-$127k',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=613008&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_900b85cd&cb=1558378184574&jobListingId=3197744367'},
#    {'Name': 'Data Engineer',
#     'Company': ' Califia Farms  ',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=588939&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_affdbd3c&cb=1558378184575&jobListingId=3030720576'},
#    {'Name': 'Director, Software Engineering (Front End)',
#     'Company': ' MomentFeed  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=641381&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_fc42d762&cb=1558378184576&jobListingId=3235579801'},
#    {'Name': 'Data Engineer',
#     'Company': ' PlayQ  ',
#     'State': 'CA',
#     'City': 'Santa Monica',
#     'Salary': '',
#     'Location': 'Santa Monica, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=8095&s=58&guid=0000016ad693fb43b15bb8f4c148310d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c050877e&cb=1558378184577&jobListingId=3005431426'}]}}

# %%
result_dict['data scientist'].keys()
# Out:
# dict_keys(['san diego', 'los angeles'])

# %%
result_dict['data engineer'].keys()
# Out:
# dict_keys(['san diego', 'los angeles'])

# %%
result_dict['data analyst'].keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-3bb010309ba1> in <module>
# ----> 1 result_dict['data analyst'].keys()
#
# KeyError: 'data analyst'

# %%
result_dict['data scientist']['san diego']
# Out:
# [{'Name': 'Data Scientist',
#   'Company': ' Dexcom  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$95k-$134k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=296910&s=149&guid=0000016ad69398078266b94020925512&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cba900ae&cb=1558378158749&jobListingId=3129909498'},
#  {'Name': 'Senior Data Scientist',
#   'Company': ' Tealium  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$143k-$191k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=642403&s=149&guid=0000016ad69398078266b94020925512&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8f67c27b&cb=1558378158751&jobListingId=3232692044'},
#  {'Name': 'Machine Learning Engineer - Data Analysis',
#   'Company': ' Samsung Semiconductor, Inc.  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$99k-$134k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=630701&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a8746cc1&cb=1558378158752&jobListingId=3223997059'},
#  {'Name': 'Data Engineer',
#   'Company': ' LeadCrunch  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$125k-$155k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=535387&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_81cb9612&cb=1558378158753&jobListingId=2996249774'},
#  {'Name': 'Scientist I',
#   'Company': ' Takeda Pharmaceuticals  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$88k-$121k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=488112&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e47998bd&cb=1558378158754&jobListingId=3233298933'},
#  {'Name': 'Data Scientist',
#   'Company': ' Indeed Prime  New',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=437638&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2ea6999b&cb=1558378158755&jobListingId=3042963556'},
#  {'Name': 'Data Analyst',
#   'Company': ' Mindstream Media  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$40k-$63k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=535423&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_703aae88&cb=1558378158756&jobListingId=3103048891'},
#  {'Name': 'Data Scientist (Machine Learning)',
#   'Company': ' Experian  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$101k-$137k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=610985&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9ca1bcb5&cb=1558378158757&jobListingId=3232187804'},
#  {'Name': 'Staff Scientist',
#   'Company': ' Illumina  Top Company',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7980c219&cb=1558378158799&jobListingId=3125952519'},
#  {'Name': 'Senior Scientist',
#   'Company': ' Illumina  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$104k-$140k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_655a22c4&cb=1558378158810&jobListingId=3158761344'},
#  {'Name': '#99510 (CLS) Clinical Lab Scientist Specialist',
#   'Company': ' UC San Diego  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$32-$45\xa0per hour',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=4120&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_44a6a3f8&cb=1558378158811&jobListingId=3235492301'},
#  {'Name': 'Staff Data Scientist',
#   'Company': ' National Funding  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$121k-$171k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=541807&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_16230220&cb=1558378158813&jobListingId=3122353252'},
#  {'Name': 'Principal Scientist',
#   'Company': ' Takeda Pharmaceuticals  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$121k-$162k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=488112&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_081a1578&cb=1558378158814&jobListingId=3189007535'},
#  {'Name': 'Scientist 1',
#   'Company': ' Illumina  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$72k-$96k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3cbd8eca&cb=1558378158815&jobListingId=3107155666'},
#  {'Name': 'Principal Scientist, Biomarkers and Companion Diagnostics',
#   'Company': ' Rakuten Medical  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=78823&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2e1819eb&cb=1558378158816&jobListingId=3234939918'},
#  {'Name': 'Bioinformatics Scientist',
#   'Company': ' Illumina  Top Company',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=484648&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_21ac0118&cb=1558378158818&jobListingId=3198811559'},
#  {'Name': 'Senior Data Scientist',
#   'Company': ' ICW Group  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$122k-$164k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=523741&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2d194bd4&cb=1558378158818&jobListingId=3188967021'},
#  {'Name': 'Data Analyst',
#   'Company': ' Encore Capital Group  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$49k-$76k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=413637&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2340851b&cb=1558378158820&jobListingId=3216549600'},
#  {'Name': 'Software Engineer (Data Analysis)',
#   'Company': ' ASML  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$82k-$139k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=580354&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_dd8ee489&cb=1558378158821&jobListingId=3199423402'},
#  {'Name': 'Data Scientist',
#   'Company': ' Broadcom  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$114k-$154k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=242900&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b1768118&cb=1558378158822&jobListingId=3076652924'},
#  {'Name': 'DATA SCIENTIST - ACO',
#   'Company': ' Scripps Health  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$90k-$122k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=182759&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3be8dc0d&cb=1558378158824&jobListingId=3229941259'},
#  {'Name': 'Data Scientist - Analytics and Cognitive (Government)',
#   'Company': ' Deloitte  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$116k-$160k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=144580&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_14cc83ed&cb=1558378158825&jobListingId=3152099627'},
#  {'Name': 'Computer Scientist',
#   'Company': ' SPAWAR Systems Center Pacific  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$65k-$125k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=544406&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_6883e82d&cb=1558378158826&jobListingId=3133341553'},
#  {'Name': 'Data Scientist',
#   'Company': ' Amazon  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$115k-$157k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=133043&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c4b85a53&cb=1558378158827&jobListingId=3090515165'},
#  {'Name': 'Associate Scientist II - Immunology',
#   'Company': ' Johnson & Johnson  Top Company',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=321738&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cd7068bd&cb=1558378158828&jobListingId=3236109516'},
#  {'Name': 'Data Scientist Intern',
#   'Company': ' Housecall Pro  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=215203&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5f8c29f7&cb=1558378158829&jobListingId=3226356078'},
#  {'Name': 'Data Scientist / Deep Learning Engineer',
#   'Company': ' Intel  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$100k-$136k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=132930&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b62c1ab9&cb=1558378158830&jobListingId=3180980559'},
#  {'Name': 'Data Scientist',
#   'Company': ' Booz Allen Hamilton Inc.  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$93k-$139k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=134088&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7b4c075d&cb=1558378158831&jobListingId=3025037807'},
#  {'Name': 'Data Scientist Intern',
#   'Company': ' Experian  ',
#   'State': 'CA',
#   'City': 'El Cajon',
#   'Salary': '',
#   'Location': 'El Cajon, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=200539&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c50f194e&cb=1558378158832&jobListingId=3232186494'},
#  {'Name': 'Data Science Intern',
#   'Company': ' Cuker  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=4120&s=58&guid=0000016ad69398079b9f1e5326d260a6&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7ea2767d&cb=1558378158833&jobListingId=3173130340'}]

# %%
result_dict['data scientist']['los angeles']
# Out:
# [{'Name': 'Data Scientist Senior',
#   'Company': ' Capital Group  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$115k-$155k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=360325&s=149&guid=0000016ad693b93da338f235b017c77e&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5bd46239&cb=1558378167211&jobListingId=3136656764'},
#  {'Name': 'Data Scientist',
#   'Company': ' Thrive Market  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$106k-$146k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=556693&s=149&guid=0000016ad693b93da338f235b017c77e&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cfe87e4d&cb=1558378167213&jobListingId=3221727527'},
#  {'Name': 'Data Scientist',
#   'Company': ' Rubicon Project  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$116k-$157k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=601125&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c2175a97&cb=1558378167214&jobListingId=3123198897'},
#  {'Name': 'Data Scientist',
#   'Company': ' Indeed Prime  New',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=437627&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7c764e02&cb=1558378167215&jobListingId=3042963551'},
#  {'Name': 'Data Engineer',
#   'Company': ' Capital Group  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$110k-$148k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=211228&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_02f19599&cb=1558378167216&jobListingId=3216658621'},
#  {'Name': 'Data Scientist, Machine Learning',
#   'Company': ' ZestFinance  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$105k-$142k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=498820&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_876f08b1&cb=1558378167217&jobListingId=3018182751'},
#  {'Name': 'Data Scientist - New Grad',
#   'Company': ' Beyond Limits  ',
#   'State': 'CA',
#   'City': 'Glendale',
#   'Salary': '$128k-$185k',
#   'Location': 'Glendale, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=4128&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_42d389cb&cb=1558378167219&jobListingId=3008596745'},
#  {'Name': 'Data Scientist',
#   'Company': " Jobot  We're Hiring",
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=594271&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8ffb5d1e&cb=1558378167220&jobListingId=3226583477'},
#  {'Name': 'Data Scientist - Platform',
#   'Company': ' Inspire  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$82k-$115k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=570001&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_181f2066&cb=1558378167222&jobListingId=3191351179'},
#  {'Name': 'Data Scientist, Product Analytics',
#   'Company': ' BuzzFeed  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$110k-$154k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=4120&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_1505cdf0&cb=1558378167223&jobListingId=3231063575'},
#  {'Name': 'Data Scientist',
#   'Company': ' Walt Disney Company  ',
#   'State': 'CA',
#   'City': 'Burbank',
#   'Salary': '$112k-$153k',
#   'Location': 'Burbank, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=191997&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3f1827dc&cb=1558378167225&jobListingId=3233583443'},
#  {'Name': 'Associate Data Scientist',
#   'Company': ' Sense360  Hot',
#   'State': 'CA',
#   'City': 'Culver City',
#   'Salary': '',
#   'Location': 'Culver City, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=215203&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_18896142&cb=1558378167226&jobListingId=3159337730'},
#  {'Name': 'Junior Data Scientist',
#   'Company': ' Ranker  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$91k-$133k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=7438&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_89400fb1&cb=1558378167227&jobListingId=3187767725'},
#  {'Name': 'Data Scientist',
#   'Company': ' Roku  ',
#   'State': 'CA',
#   'City': 'Santa Monica',
#   'Salary': '$149k-$199k',
#   'Location': 'Santa Monica, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=136412&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_b60ecc52&cb=1558378167228&jobListingId=3183454466'},
#  {'Name': 'Data Scientist',
#   'Company': ' Schlumberger  ',
#   'State': 'CA',
#   'City': 'Pasadena',
#   'Salary': '$99k-$142k',
#   'Location': 'Pasadena, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=400784&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2044bfd1&cb=1558378167230&jobListingId=3137356443'},
#  {'Name': 'Sr Data Scientist',
#   'Company': ' Neustar  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$110k-$148k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=610217&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7591936a&cb=1558378167232&jobListingId=3190366941'},
#  {'Name': 'Data Scientist',
#   'Company': ' Genuent  ',
#   'State': 'CA',
#   'City': 'Burbank',
#   'Salary': '$105k-$145k',
#   'Location': 'Burbank, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=83255&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_84f66d67&cb=1558378167233&jobListingId=3214605433'},
#  {'Name': 'Data Scientist Organizational Performance',
#   'Company': ' Southern California Edison  ',
#   'State': 'CA',
#   'City': 'Rosemead',
#   'Salary': '$108k-$149k',
#   'Location': 'Rosemead, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=398947&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a2f1c5cb&cb=1558378167234&jobListingId=3156833700'},
#  {'Name': 'Senior Data Scientist',
#   'Company': ' Headspace  ',
#   'State': 'CA',
#   'City': 'Santa Monica',
#   'Salary': '$139k-$188k',
#   'Location': 'Santa Monica, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=524781&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_03e2ff3c&cb=1558378167235&jobListingId=3067455252'},
#  {'Name': 'Data Scientist',
#   'Company': ' Sony Pictures Entertainment  ',
#   'State': 'CA',
#   'City': 'Culver City',
#   'Salary': '$117k-$164k',
#   'Location': 'Culver City, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=242900&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2d5f77a5&cb=1558378167236&jobListingId=3183128471'},
#  {'Name': 'Data Scientist',
#   'Company': ' Unilever  ',
#   'State': 'CA',
#   'City': 'Marina del Rey',
#   'Salary': '$92k-$128k',
#   'Location': 'Marina del Rey, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=400784&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_aed51eb1&cb=1558378167238&jobListingId=3189602874'},
#  {'Name': 'Data Scientist ( Risk / Quantitative )',
#   'Company': ' Ascent  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$83k-$124k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=157444&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_24ef970d&cb=1558378167239&jobListingId=3222084662'},
#  {'Name': 'Junior Data Scientist',
#   'Company': ' Fama (CA)  ',
#   'State': 'CA',
#   'City': 'Playa Vista',
#   'Salary': '',
#   'Location': 'Playa Vista, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=4120&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cd7fd631&cb=1558378167240&jobListingId=2905612987'},
#  {'Name': 'Data Scientist',
#   'Company': ' Aspiration  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$97k-$131k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=148364&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_755696d1&cb=1558378167242&jobListingId=3211087380'},
#  {'Name': 'Data Scientist, Advertising',
#   'Company': ' Los Angeles Times  ',
#   'State': 'CA',
#   'City': 'El Segundo',
#   'Salary': '$116k-$159k',
#   'Location': 'El Segundo, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=242900&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f9000f5c&cb=1558378167243&jobListingId=3180202701'},
#  {'Name': 'Data Scientist',
#   'Company': ' Dollar Shave Club  ',
#   'State': 'CA',
#   'City': 'Marina del Rey',
#   'Salary': '$104k-$144k',
#   'Location': 'Marina del Rey, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=136357&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_14716143&cb=1558378167245&jobListingId=3187588596'},
#  {'Name': 'Data Scientist - League of Legends',
#   'Company': ' Riot Games  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$113k-$151k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=133118&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_6092edfe&cb=1558378167247&jobListingId=3203719223'},
#  {'Name': 'Data Scientist',
#   'Company': ' Allrecipes.com  ',
#   'State': 'CA',
#   'City': 'Los Angeles',
#   'Salary': '$90k-$123k',
#   'Location': 'Los Angeles, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=352789&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_846eea1d&cb=1558378167249&jobListingId=3124885861'},
#  {'Name': 'Data Scientist',
#   'Company': ' Aquent  ',
#   'State': 'CA',
#   'City': 'El Segundo',
#   'Salary': '',
#   'Location': 'El Segundo, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=636746&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7003a458&cb=1558378167250&jobListingId=3232254253'},
#  {'Name': 'Data Scientist',
#   'Company': ' Amazon  ',
#   'State': 'CA',
#   'City': 'Santa Monica',
#   'Salary': '$115k-$158k',
#   'Location': 'Santa Monica, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=133043&s=58&guid=0000016ad693b93d8f6ffe54652b036e&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9dd9c64f&cb=1558378167251&jobListingId=3234591396'}]

# %%
result_dict['data scientist']['san francisco']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-171677924289> in <module>
# ----> 1 result_dict['data scientist']['san francisco']
#
# KeyError: 'san francisco'

# %%
result_dict['data scientist']['denver']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f4d266e677ed> in <module>
# ----> 1 result_dict['data scientist']['denver']
#
# KeyError: 'denver'

# %%
result_dict['data scientist']['austin']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-ecebbb688795> in <module>
# ----> 1 result_dict['data scientist']['austin']
#
# KeyError: 'austin'

# %%
result_dict['data scientist']['new york']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-a8a089830444> in <module>
# ----> 1 result_dict['data scientist']['new york']
#
# KeyError: 'new york'

# %%
result_dict['data engineer']['san diego']
# Out:
# [{'Name': 'Data Engineer',
#   'Company': ' LeadCrunch  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$125k-$155k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=535387&s=149&guid=0000016ad693d9d09ad14d33216866a9&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_268dba92&cb=1558378175734&jobListingId=2996249774'},
#  {'Name': 'Machine Learning Engineer - Data Analysis',
#   'Company': ' Samsung Semiconductor, Inc.  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$99k-$134k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=630701&s=149&guid=0000016ad693d9d09ad14d33216866a9&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0f324041&cb=1558378175736&jobListingId=3223997059'},
#  {'Name': 'Front End Engineer',
#   'Company': ' foresee medical, inc.  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=526615&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7d575d07&cb=1558378175737&jobListingId=2613473725'},
#  {'Name': 'Data Analyst',
#   'Company': ' Mindstream Media  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$40k-$63k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=535423&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_208b4cd4&cb=1558378175738&jobListingId=3103048891'},
#  {'Name': 'Software Engineer',
#   'Company': ' Cognetic Technologies  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$50-$55\xa0per hour',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=539628&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_1388c79c&cb=1558378175739&jobListingId=3132166147'},
#  {'Name': 'Data Engineer',
#   'Company': ' Indeed Prime  New',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=437638&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c6d177be&cb=1558378175740&jobListingId=3042963969'},
#  {'Name': 'Software Engineer',
#   'Company': ' Illumina  Top Company',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=484655&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cae9bdf3&cb=1558378175741&jobListingId=3141416821'},
#  {'Name': 'Test Engineer - Navy UUV',
#   'Company': ' Peraton  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$69k-$95k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=347162&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9072d161&cb=1558378175742&jobListingId=3235848644'},
#  {'Name': 'Data Analyst',
#   'Company': ' Encore Capital Group  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$49k-$76k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=413637&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3d52ab7e&cb=1558378175743&jobListingId=3216549600'},
#  {'Name': 'Senior Data Engineer',
#   'Company': ' Dexcom  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$93k-$121k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=296869&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_90c0f452&cb=1558378175744&jobListingId=3115453635'},
#  {'Name': 'Software Test Engineer',
#   'Company': ' TrellisWare Technologies, Inc  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$76k-$109k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=514670&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_f0da3c33&cb=1558378175745&jobListingId=3234916061'},
#  {'Name': 'Senior Data Scientist',
#   'Company': ' Tealium  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$143k-$191k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=642403&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_125bf25e&cb=1558378175746&jobListingId=3232692044'},
#  {'Name': 'Data Scientist (Machine Learning)',
#   'Company': ' Experian  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$101k-$137k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=610985&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b217e569&cb=1558378175747&jobListingId=3232187804'},
#  {'Name': 'Data Scientist',
#   'Company': ' Dexcom  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$95k-$134k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=296910&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_00e447ee&cb=1558378175748&jobListingId=3129909498'},
#  {'Name': 'NLP Engineer',
#   'Company': ' foresee medical, inc.  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=526614&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ead041cf&cb=1558378175750&jobListingId=2621215401'},
#  {'Name': 'Software Engineer I',
#   'Company': ' MINDBODY, Inc  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$84k-$142k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=501515&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c23b06ed&cb=1558378175751&jobListingId=3195161977'},
#  {'Name': 'Intern, Data Insights',
#   'Company': ' Coupa Software, Inc.  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=297524&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b5d0f7c5&cb=1558378175752&jobListingId=3120295127'},
#  {'Name': 'Software Engineer , IoS',
#   'Company': ' GoPro  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$79k-$132k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=586197&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_35b2684d&cb=1558378175753&jobListingId=3162452015'},
#  {'Name': 'Backend Engineer (SD)',
#   'Company': ' Health IQ  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$90k-$115k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=599151&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_00cb4f51&cb=1558378175754&jobListingId=2881641770'},
#  {'Name': 'Software Engineer',
#   'Company': ' Electric Cryotherapy  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=582952&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_7f88479f&cb=1558378175755&jobListingId=3115832877'},
#  {'Name': 'Data Architect',
#   'Company': ' ICW Group  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$102k-$145k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=523745&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_dda0d541&cb=1558378175756&jobListingId=3118871624'},
#  {'Name': 'Data Engineer',
#   'Company': ' ClosingCorp  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$79k-$108k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=8095&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_bc702e16&cb=1558378175757&jobListingId=3080913324'},
#  {'Name': 'Data Engineer',
#   'Company': ' Illumina  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$87k-$117k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=133652&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a568a643&cb=1558378175759&jobListingId=3203897143'},
#  {'Name': 'Software Engineer (Data Analysis)',
#   'Company': ' ASML  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$82k-$139k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=580354&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8d3f06d5&cb=1558378175760&jobListingId=3199423402'},
#  {'Name': 'Data Engineer',
#   'Company': ' TEKsystems, Inc  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=320811&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0e5ba476&cb=1558378175761&jobListingId=3235690817'},
#  {'Name': 'Data Scientist',
#   'Company': ' Amazon  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$115k-$157k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=133043&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7f70c8b0&cb=1558378175762&jobListingId=3090515165'},
#  {'Name': 'Systems Engineer',
#   'Company': ' Dimension Data  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=251292&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_49de3bcb&cb=1558378175763&jobListingId=2828058683'},
#  {'Name': 'Data Scientist Intern',
#   'Company': ' Experian  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=200539&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_276b0446&cb=1558378175764&jobListingId=3232184149'},
#  {'Name': 'Systems Verification Test Engineer',
#   'Company': ' ATX Networks  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=534048&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_df84b41f&cb=1558378175765&jobListingId=2784104970'},
#  {'Name': 'Data Engineer',
#   'Company': ' Petco  ',
#   'State': 'CA',
#   'City': 'San Diego',
#   'Salary': '$76k-$103k',
#   'Location': 'San Diego, CA',
#   'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=182759&s=58&guid=0000016ad693d9d0b5bdfe91be2dc347&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_104f2d00&cb=1558378175766&jobListingId=3224426668'}]

# %%
result_dict['data analyst']['new york']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-1f71e7cab134> in <module>
# ----> 1 result_dict['data analyst']['new york']
#
# KeyError: 'data analyst'

# %%
from flask import Flask
from flask_pymongo import PyMongo

app = Flask(__name__)
uri = 'mongodb+srv://gil:bert@cluster0-8wvjx.mongodb.net/project2?retryWrites=true'
mongo = PyMongo(app, uri=uri)

mongo.db.housing.update({}, result_dict, upsert=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# {'n': 1,
#  'nModified': 0,
#  'upserted': ObjectId('5ce2f713a7a4282b0589ce41'),
#  'opTime': {'ts': Timestamp(1558378259, 2), 't': 2},
#  'electionId': ObjectId('7fffffff0000000000000002'),
#  'ok': 1.0,
#  'operationTime': Timestamp(1558378259, 2),
#  '$clusterTime': {'clusterTime': Timestamp(1558378259, 2),
#   'signature': {'hash': b'\xfb|\xb7\xef\x93\xbd3>U\xcc\xc4mc.\xd0j\xf9\\\xf6b',
#    'keyId': 6681343450274594817}},
#  'updatedExisting': False}

# %%
# save to json
import json

with open('data.json', 'w') as fp:
    json.dump(result_dict, fp)

# %%
# retrieve data from mongoDB and load to variable
from flask import Flask
from flask_pymongo import PyMongo

app = Flask(__name__)
uri = 'mongodb+srv://gil:bert@cluster0-8wvjx.mongodb.net/project2?retryWrites=true'
mongo = PyMongo(app, uri=uri)

data = mongo.db.housing.find_one()

# %%
data
