# %%
import argparse
import json
import os
import re
import requests
import sys
import time
import unicodecsv as csv

from flask import Flask
from flask_pymongo import PyMongo
from geopy.geocoders import Nominatim
from lxml import html, etree

# mongoDB setup
app = Flask(__name__)
uri = 'mongodb+srv://gil:bert@cluster0-8wvjx.mongodb.net/project2?retryWrites=true'
mongo = PyMongo(app, uri=uri)

# define main function to retrive job listings based on keyword and place. single varibles or lists can be passed.
def parse(keyword, place):
    headers = {	'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
                'accept-encoding': 'gzip, deflate, sdch, br',
                'accept-language': 'en-GB,en-US;q=0.8,en;q=0.6',
                'referer': 'https://www.glassdoor.com/',
                'upgrade-insecure-requests': '1',
                'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/51.0.2704.79 Chrome/51.0.2704.79 Safari/537.36',
                'Cache-Control': 'no-cache',
                'Connection': 'keep-alive'
        }

    location_headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.01',
        'accept-encoding': 'gzip, deflate, sdch, br',
        'accept-language': 'en-GB,en-US;q=0.8,en;q=0.6',
        'referer': 'https://www.glassdoor.com/',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/51.0.2704.79 Chrome/51.0.2704.79 Safari/537.36',
        'Cache-Control': 'no-cache',
        'Connection': 'keep-alive'
    }
    
    data = {"term": place, "maxLocationsToReturn": 50}
    location_url = "https://www.glassdoor.co.in/findPopularLocationAjax.htm?"
    try:
#        # Getting location id for search location
        print(f"Retrieving job listings for {keyword} in {place}.")
        location_response = requests.post(location_url, headers=location_headers, data=data).json()
        place_id = location_response[0]['locationId']
        job_listing_url = 'https://www.glassdoor.com/Job/jobs.htm'
        # Form data to get job results
        data = {
            'clickSource': 'searchBtn',
            'sc.keyword': keyword,
            'locT': 'C',
            'locId': place_id,
            'jobType': ''
        }

        job_listings = []
        if place_id:
            response = requests.post(job_listing_url, headers=headers, data=data)
            # extracting data from
            # https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=true&clickSource=searchBtn&typedKeyword=andr&sc.keyword=android+developer&locT=C&locId=1146821&jobType=
            parser = html.fromstring(response.text)
            # Making absolute url 
            base_url = "https://www.glassdoor.com"
            parser.make_links_absolute(base_url)

            XPATH_ALL_JOB = '//li[@class="jl"]'
            XPATH_NAME = './/a/text()'
            XPATH_JOB_URL = './/a/@href'
            XPATH_LOC = './/span[@class="subtle loc"]/text()'
            XPATH_COMPANY = './/div[@class="flexbox empLoc"]/div/text()'
            XPATH_SALARY = './/span[@class="green small"]/text()'

            listings = parser.xpath(XPATH_ALL_JOB)
            for job in listings:
                raw_job_name = job.xpath(XPATH_NAME)
                raw_job_url = job.xpath(XPATH_JOB_URL)
                raw_lob_loc = job.xpath(XPATH_LOC)
                raw_company = job.xpath(XPATH_COMPANY)
                raw_salary = job.xpath(XPATH_SALARY)

                # Cleaning data
                job_name = ''.join(raw_job_name).strip('–') if raw_job_name else None
                job_location = ''.join(raw_lob_loc) if raw_lob_loc else None
                raw_state = re.findall(",\s?(.*)\s?", job_location)
                state = ''.join(raw_state).strip()
                raw_city = job_location.replace(state, '')
                city = raw_city.replace(',', '').strip()
                company = ''.join(raw_company).replace('–','')
                salary = ''.join(raw_salary).strip()
                job_url = raw_job_url[0] if raw_job_url else None

                jobs = {
                    "Name": job_name,
                    "Company": company,
                    "State": state,
                    "City": city,
                    "Salary": salary,
                    "Location": job_location,
                    "Url": job_url
                }
                job_listings.append(jobs)
            return job_listings
        else:
            print("location id not available")

    except:
        print("Failed to load locations")

    if __name__ == "__main__":

#     ''' eg-:python 1934_glassdoor.py "Android developer", "new york" '''

        argparser = argparse.ArgumentParser()
        argparser.add_argument('keyword', help='job name', type=str)
        argparser.add_argument('place', help='job location', type=str)
        args = argparser.parse_args()
        keyword = args.keyword
        place = args.place
        print("Fetching job details")
        scraped_data = parse(keyword, place)
        print("Writing data to output file")

        with open('%s-%s-job-results.csv' % (keyword, place), 'wb')as csvfile:
            fieldnames = ['Name', 'Company', 'State', 'City', 'Salary', 'Location', 'Url']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames,quoting=csv.QUOTE_ALL)
            writer.writeheader()
            if scraped_data:
                for data in scraped_data:
                    writer.writerow(data)
            else:
                print("Your search for %s, in %s does not match any jobs"%(keyword,place))

# %%
# declare lists to pass to the parse function
search_job = ['Data Scientist', 'Data Engineer', 'Data Analyst', 'Statistician', 'Data Analytics Manager']
search_city = ['Ann Arbor', 'Atlanta', 'Austin', 'Boston', 'Charlotte', 'Chicago', 'Cincinnati', 'Columbia', 'Dallas', 'Denver', 'Houston', 'Jacksonville', 'Los Angeles', 'Louisville', 'Miami', 'Minneapolis', 'Nashville', 'New York', 'Newport News', 'Phoenix', 'San Diego', 'San Francisco', 'Seattle', 'Virginia Beach']

# test variables to save time
# search_job = ['Data Scientist', 'Data Engineer']
# search_city = ['San Diego', 'Los Angeles']

# %%
# multi-nested loops to build a dictionary with job as the primary key, then city as the sub keys for job listings.
# the innermost loop will check listings and filter by job
data = {}

for job in search_job:
    # new dictionary for city
    city_dict = {}
    
    for city in search_city:
        # list to save unique job listings
        filter_list = []
        # load to dictionary with city as the key
#         city_dict[(f'{city}')] = parse(job, city)
        city_dict[city] = parse(job, city)

        for listing in city_dict[city]:
            if job in listing['Name']:
#                 print(listing['Name'])
                for key in listing:
                    if listing[key] == '':
                        listing[key] = '?'
                filter_list.append(listing)
        city_dict[(f'{city}')] = filter_list
    # load to dictionary with job as the key
#     result_dict[(f'{job}')] = city_dict
    data[job] = city_dict
# Out:
# Retrieving job listings for Data Scientist in Ann Arbor.
# Retrieving job listings for Data Scientist in Atlanta.
# Retrieving job listings for Data Scientist in Austin.
# Retrieving job listings for Data Scientist in Boston.
# Retrieving job listings for Data Scientist in Charlotte.
# Retrieving job listings for Data Scientist in Chicago.
# Retrieving job listings for Data Scientist in Cincinnati.
# Retrieving job listings for Data Scientist in Columbia.
# Retrieving job listings for Data Scientist in Dallas.
# Retrieving job listings for Data Scientist in Denver.
# Retrieving job listings for Data Scientist in Houston.
# Retrieving job listings for Data Scientist in Jacksonville.
# Retrieving job listings for Data Scientist in Los Angeles.
# Retrieving job listings for Data Scientist in Louisville.
# Retrieving job listings for Data Scientist in Miami.
# Retrieving job listings for Data Scientist in Minneapolis.
# Retrieving job listings for Data Scientist in Nashville.
# Retrieving job listings for Data Scientist in New York.
# Retrieving job listings for Data Scientist in Newport News.
# Retrieving job listings for Data Scientist in Phoenix.
# Retrieving job listings for Data Scientist in San Diego.
# Retrieving job listings for Data Scientist in San Francisco.
# Retrieving job listings for Data Scientist in Seattle.
# Retrieving job listings for Data Scientist in Virginia Beach.
# Retrieving job listings for Data Engineer in Ann Arbor.
# Retrieving job listings for Data Engineer in Atlanta.
# Retrieving job listings for Data Engineer in Austin.
# Retrieving job listings for Data Engineer in Boston.
# Retrieving job listings for Data Engineer in Charlotte.
# Retrieving job listings for Data Engineer in Chicago.
# Retrieving job listings for Data Engineer in Cincinnati.
# Retrieving job listings for Data Engineer in Columbia.
# Retrieving job listings for Data Engineer in Dallas.
# Retrieving job listings for Data Engineer in Denver.
# Retrieving job listings for Data Engineer in Houston.
# Retrieving job listings for Data Engineer in Jacksonville.
# Retrieving job listings for Data Engineer in Los Angeles.
# Retrieving job listings for Data Engineer in Louisville.
# Retrieving job listings for Data Engineer in Miami.
# Retrieving job listings for Data Engineer in Minneapolis.
# Retrieving job listings for Data Engineer in Nashville.
# Retrieving job listings for Data Engineer in New York.
# Retrieving job listings for Data Engineer in Newport News.
# Retrieving job listings for Data Engineer in Phoenix.
# Retrieving job listings for Data Engineer in San Diego.
# Retrieving job listings for Data Engineer in San Francisco.
# Retrieving job listings for Data Engineer in Seattle.
# Retrieving job listings for Data Engineer in Virginia Beach.
# Retrieving job listings for Data Analyst in Ann Arbor.
# Retrieving job listings for Data Analyst in Atlanta.
# Retrieving job listings for Data Analyst in Austin.
# Retrieving job listings for Data Analyst in Boston.
# Retrieving job listings for Data Analyst in Charlotte.
# Retrieving job listings for Data Analyst in Chicago.
# Retrieving job listings for Data Analyst in Cincinnati.
# Retrieving job listings for Data Analyst in Columbia.
# Retrieving job listings for Data Analyst in Dallas.
# Retrieving job listings for Data Analyst in Denver.
# Retrieving job listings for Data Analyst in Houston.
# Retrieving job listings for Data Analyst in Jacksonville.
# Retrieving job listings for Data Analyst in Los Angeles.
# Retrieving job listings for Data Analyst in Louisville.
# Retrieving job listings for Data Analyst in Miami.
# Retrieving job listings for Data Analyst in Minneapolis.
# Retrieving job listings for Data Analyst in Nashville.
# Retrieving job listings for Data Analyst in New York.
# Retrieving job listings for Data Analyst in Newport News.
# Retrieving job listings for Data Analyst in Phoenix.
# Retrieving job listings for Data Analyst in San Diego.
# Retrieving job listings for Data Analyst in San Francisco.
# Retrieving job listings for Data Analyst in Seattle.
# Retrieving job listings for Data Analyst in Virginia Beach.
# Retrieving job listings for Statistician in Ann Arbor.
# Retrieving job listings for Statistician in Atlanta.
# Retrieving job listings for Statistician in Austin.
# Retrieving job listings for Statistician in Boston.
# Retrieving job listings for Statistician in Charlotte.
# Retrieving job listings for Statistician in Chicago.
# Retrieving job listings for Statistician in Cincinnati.
# Retrieving job listings for Statistician in Columbia.
# Retrieving job listings for Statistician in Dallas.
# Retrieving job listings for Statistician in Denver.
# Retrieving job listings for Statistician in Houston.
# Retrieving job listings for Statistician in Jacksonville.
# Retrieving job listings for Statistician in Los Angeles.
# Retrieving job listings for Statistician in Louisville.
# Retrieving job listings for Statistician in Miami.
# Retrieving job listings for Statistician in Minneapolis.
# Retrieving job listings for Statistician in Nashville.
# Retrieving job listings for Statistician in New York.
# Retrieving job listings for Statistician in Newport News.
# Retrieving job listings for Statistician in Phoenix.
# Retrieving job listings for Statistician in San Diego.
# Retrieving job listings for Statistician in San Francisco.
# Retrieving job listings for Statistician in Seattle.
# Retrieving job listings for Statistician in Virginia Beach.
# Retrieving job listings for Data Analytics Manager in Ann Arbor.
# Retrieving job listings for Data Analytics Manager in Atlanta.
# Retrieving job listings for Data Analytics Manager in Austin.
# Retrieving job listings for Data Analytics Manager in Boston.
# Retrieving job listings for Data Analytics Manager in Charlotte.
# Retrieving job listings for Data Analytics Manager in Chicago.
# Retrieving job listings for Data Analytics Manager in Cincinnati.
# Retrieving job listings for Data Analytics Manager in Columbia.
# Retrieving job listings for Data Analytics Manager in Dallas.
# Retrieving job listings for Data Analytics Manager in Denver.
# Retrieving job listings for Data Analytics Manager in Houston.
# Retrieving job listings for Data Analytics Manager in Jacksonville.
# Retrieving job listings for Data Analytics Manager in Los Angeles.
# Retrieving job listings for Data Analytics Manager in Louisville.
# Retrieving job listings for Data Analytics Manager in Miami.
# Retrieving job listings for Data Analytics Manager in Minneapolis.
# Retrieving job listings for Data Analytics Manager in Nashville.
# Retrieving job listings for Data Analytics Manager in New York.
# Retrieving job listings for Data Analytics Manager in Newport News.
# Retrieving job listings for Data Analytics Manager in Phoenix.
# Retrieving job listings for Data Analytics Manager in San Diego.
# Retrieving job listings for Data Analytics Manager in San Francisco.
# Retrieving job listings for Data Analytics Manager in Seattle.
# Retrieving job listings for Data Analytics Manager in Virginia Beach.

# %%
data
# Out:
# {'Data Scientist': {'Ann Arbor': [{'Name': 'Data Scientist',
#     'Company': ' AVL Instrumentation & Test Systems  ',
#     'State': 'MI',
#     'City': 'Plymouth',
#     'Salary': '$108k-$147k',
#     'Location': 'Plymouth, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=622086&s=149&guid=0000016af18f45e3b5e2bfdf7db245bf&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a0fe42ed&cb=1558830860520&jobListingId=3214814911'},
#    {'Name': 'Data Scientist (Marketing Science)',
#     'Company': " Domino's  ",
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '$80k-$90k',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=359453&s=149&guid=0000016af18f45e3b5e2bfdf7db245bf&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8e3dde43&cb=1558830860521&jobListingId=3203079211'},
#    {'Name': 'Data Scientist',
#     'Company': ' Daimler  ',
#     'State': 'MI',
#     'City': 'Farmington Hills',
#     'Salary': '$111k-$152k',
#     'Location': 'Farmington Hills, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=3839&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_81bef950&cb=1558830860524&jobListingId=3235559884'},
#    {'Name': 'Data Scientist',
#     'Company': ' KBTS Technologies, Inc.  ',
#     'State': 'MI',
#     'City': 'Novi',
#     'Salary': '$75k-$107k',
#     'Location': 'Novi, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=83255&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_532a7b5f&cb=1558830860525&jobListingId=3243378598'},
#    {'Name': 'Data Scientist',
#     'Company': ' Mercedes-Benz Financial Services USA LLC  ',
#     'State': 'MI',
#     'City': 'Farmington Hills',
#     'Salary': '$100k-$137k',
#     'Location': 'Farmington Hills, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=3839&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_515069b5&cb=1558830860525&jobListingId=3235958524'},
#    {'Name': 'Data Scientist (A/B Testing / Digital Analytics)',
#     'Company': " Domino's  ",
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '$80k-$90k',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=359453&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3693b911&cb=1558830860526&jobListingId=3203079210'},
#    {'Name': 'Data Scientist',
#     'Company': ' DataFactZ  ',
#     'State': 'MI',
#     'City': 'Northville',
#     'Salary': '$87k-$119k',
#     'Location': 'Northville, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=352789&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0122d6a8&cb=1558830860527&jobListingId=3231814738'},
#    {'Name': 'Data Scientist',
#     'Company': ' ITHAKA  ',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '$65k-$90k',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=134121&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c4648c7f&cb=1558830860528&jobListingId=3193763939'},
#    {'Name': 'Data Scientist',
#     'Company': ' Trinity Health  ',
#     'State': 'MI',
#     'City': 'Livonia',
#     'Salary': '$90k-$122k',
#     'Location': 'Livonia, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=359914&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9ccfce3f&cb=1558830860529&jobListingId=2843045883'},
#    {'Name': 'Data Scientist',
#     'Company': ' ARCADIS US  ',
#     'State': 'MI',
#     'City': 'Novi',
#     'Salary': '$82k-$118k',
#     'Location': 'Novi, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=433326&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0b630e29&cb=1558830860530&jobListingId=3242043967'},
#    {'Name': 'Data Scientist',
#     'Company': ' Kforce  ',
#     'State': 'MI',
#     'City': 'Livonia',
#     'Salary': '?',
#     'Location': 'Livonia, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=220345&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_995d8a77&cb=1558830860531&jobListingId=3228356906'},
#    {'Name': 'Data Scientist',
#     'Company': ' AVL  ',
#     'State': 'MI',
#     'City': 'Plymouth',
#     'Salary': '$80k-$111k',
#     'Location': 'Plymouth, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=389273&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_68bbace6&cb=1558830860532&jobListingId=3216667111'},
#    {'Name': 'Data Scientist',
#     'Company': ' Econosoft  ',
#     'State': 'MI',
#     'City': 'Livonia',
#     'Salary': '?',
#     'Location': 'Livonia, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=4120&s=58&guid=0000016af18f45e389e925c3b54cbdbf&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1
&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_da3f6790&cb=1558830863903&jobListingId=3108193125'},
#    {'Name': 'Data Scientist (Labs)',
#     'Company': '?',
#     'State': 'MA',
#     'City': 'Boston',
#     'Salary': '?',
#     'Location': 'Boston, MA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=160631&s=58&guid=0000016af18f5492993750f13f6719f1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_577ee710&cb=1558830863904&jobListingId=3141825728'},
#    {'Name': 'Data Scientist, Digital Lab',
#     'Company': '?',
#     'State': 'MA',
#     'City': 'Waltham',
#     'Salary': '?',
#     'Location': 'Waltham, MA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=628349&s=58&guid=0000016af18f5492993750f13f6719f1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_d399064a&cb=1558830863905&jobListingId=3198765126'},
#    {'Name': 'Data Scientist',
#     'Company': '?',
#     'State': 'MA',
#     'City': 'Woburn',
#     'Salary': '?',
#     'Location': 'Woburn, MA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=607667&s=58&guid=0000016af18f5492993750f13f6719f1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_015de4bb&cb=1558830863907&jobListingId=2981923026'}],
#   'Charlotte': [{'Name': 'Senior Data Scientist- Modeling & Simulation',
#     'Company': ' Ingersoll-Rand  ',
#     'State': 'NC',
#     'City': 'Davidson',
#     'Salary': '$112k-$148k',
#     'Location': 'Davidson, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=361268&s=149&guid=0000016af18f587b9da8cc3590fa3546&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0fa6a948&cb=1558830864875&jobListingId=3244874547'},
#    {'Name': 'Data Scientist, Operations & Manufacturing',
#     'Company': ' Shutterfly  ',
#     'State': 'SC',
#     'City': 'Fort Mill',
#     'Salary': '$88k-$121k',
#     'Location': 'Fort Mill, SC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=206790&s=149&guid=0000016af18f587b9da8cc3590fa3546&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_16a06065&cb=1558830864876&jobListingId=3076163174'},
#    {'Name': 'Data Scientist',
#     'Company': ' Eliassen Group  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=454816&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_93eda3c8&cb=1558830864883&jobListingId=3232159559'},
#    {'Name': 'Data Scientist',
#     'Company': ' Day & Zimmermann Group  New',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=454816&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c4068bc8&cb=1558830864885&jobListingId=3244657868'},
#    {'Name': 'Data Scientist',
#     'Company': ' Veritis Group, Inc.  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=454816&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b7fec092&cb=1558830864886&jobListingId=3238876244'},
#    {'Name': 'Data Scientist',
#     'Company': ' Pandera Systems  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$100k-$136k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=4373&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cbae9f75&cb=1558830864887&jobListingId=3141925764'},
#    {'Name': 'Data Scientist',
#     'Company': ' IBM  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$86k-$121k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=140152&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b43915c5&cb=1558830864888&jobListingId=3208128739'},
#    {'Name': 'Analytic Consultant 5 - Data Scientist',
#     'Company': ' Wells Fargo  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$54k-$89k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=346072&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7b0863cb&cb=1558830864889&jobListingId=3244776064'},
#    {'Name': 'Data Scientist',
#     'Company': ' Barings  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=242900&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_257b6157&cb=1558830864890&jobListingId=3088428609'},
#    {'Name': 'Data Scientist',
#     'Company': ' SentryOne  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$80k-$117k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=237449&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e886f910&cb=1558830864891&jobListingId=3229049150'},
#    {'Name': 'Data Scientist',
#     'Company': ' Tookitaki Holding PTE LTD  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=7438&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_2872d552&cb=1558830864892&jobListingId=2969433465'},
#    {'Name': 'Data Scientist',
#     'Company': ' Driven Brands  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$69k-$98k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=209461&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_09970c61&cb=1558830864894&jobListingId=3147293033'},
#    {'Name': 'Data Scientist',
#     'Company': ' Red Ventures  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$80k-$108k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=132969&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ee26b624&cb=1558830864897&jobListingId=2761393014'},
#    {'Name': 'Data Scientist (Full time)',
#     'Company': ' Sumeru Solutions  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$82k-$116k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=352789&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_92213a8c&cb=1558830864898&jobListingId=3231702038'},
#    {'Name': 'Data Scientist, Data & Analytics',
#     'Company': ' Slalom LLC.  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$100k-$142k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=133063&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a1e27f7d&cb=1558830864899&jobListingId=3176156273'},
#    {'Name': 'Business Analytics Data Scientist',
#     'Company': ' Carolina Panthers  ',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '$61k-$89k',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=186601&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_0ffa0377&cb=1558830864901&jobListingId=3207513476'},
#    {'Name': 'Data Scientist',
#     'Company': " Lowe's  ",
#     'State': 'NC',
#     'City': 'Mooresville',
#     'Salary': '$83k-$112k',
#     'Location': 'Mooresville, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=129&ao=134580&s=58&guid=0000016af18f587b80617e2fab5ee91d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_beb1efd9&cb=1558830864906&jobListingId=3236787001'}],
#   'Chicago': [{'Name': 'Data Scientist (Pricing & Experimentation), Finance Research',
#     'Company': ' Grubhub  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$108k-$149k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=637018&s=149&guid=0000016af18f5d27be3af934ea19b752&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9c78aa84&cb=1558830866203&jobListingId=3231099518'},
#    {'Name': 'Data Scientist',
#     'Company': ' Relativity  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$92k-$125k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=585289&s=149&guid=0000016af18f5d27be3af934ea19b752&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_42ffd923&cb=1558830866204&jobListingId=3152262626'},
#    {'Name': 'Senior Data Scientist',
#     'Company': ' PEAK6  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$104k-$146k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=500389&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_f63463fc&cb=1558830866205&jobListingId=2934780042'},
#    {'Name': 'Data Scientist',
#     'Company': ' Strata Decision Technology  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$95k-$130k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=499176&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_6dee8c7e&cb=1558830866207&jobListingId=3130236684'},
#    {'Name': 'Senior Data Scientist',
#     'Company': ' Label Insight  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$116k-$156k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=520989&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_d74098ee&cb=1558830866209&jobListingId=3132938052'},
#    {'Name': 'Data Scientist',
#     'Company': ' Indeed Prime  Hot',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '?',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=437619&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e614a8fb&cb=1558830866219&jobListingId=3042963548'},
#    {'Name': 'Data Scientist',
#     'Company': ' Spectrum Communications and Consulting  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$102k-$150k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=521506&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_34bda5c6&cb=1558830866223&jobListingId=2649986689'},
#    {'Name': 'Insurance Data Scientist',
#     'Company': ' TransUnion  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$81k-$112k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=484462&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_60c84f92&cb=1558830866225&jobListingId=3176875907'},
#    {'Name': 'Senior Data Scientist',
#     'Company': ' Maven Wave Partners  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$124k-$169k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=397579&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_224deb98&cb=1558830866230&jobListingId=3182102505'},
#    {'Name': 'Machine Learning Data Scientist',
#     'Company': ' Wolverine Trading  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$97k-$138k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=596514&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5aff35d9&cb=1558830866231&jobListingId=2949493016'},
#    {'Name': 'Data Scientist',
#     'Company': ' Trunk Club  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$107k-$151k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=174237&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fccd9647&cb=1558830866232&jobListingId=3188879912'},
#    {'Name': 'Data Scientist - Credit Risk',
#     'Company': ' TransUnion  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$82k-$115k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=484462&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e6ddc2ee&cb=1558830866235&jobListingId=3176876069'},
#    {'Name': 'Data Scientist, Applied Machine Learning',
#     'Company': ' Tempus Labs  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$90k-$124k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=526926&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_3fb785b8&cb=1558830866236&jobListingId=2924064485'},
#    {'Name': 'Data Scientist for Insurance Analytics',
#     'Company': ' TransUnion  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$69k-$99k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=484462&s=58&guid=0000016af18f5d27999f0da657561212&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ff906e89&cb=1558830866237&jobListingId=3176876956'}],
#   'Cincinnati': [{'Name': 'Data Scientist-R&D',
#     'Company': ' Procter & Gamble  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '$93k-$128k',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=602297&s=149&guid=0000016af18f6227a379b37666f224ec&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_439438f5&cb=1558830867446&jobListingId=3111800984'},
#    {'Name': 'Data Scientist Marketing Focus',
#     'Company': ' Procter & Gamble  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '$89k-$121k',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=602297&s=149&guid=0000016af18f6227a379b37666f224ec&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_76122c48&cb=1558830867448&jobListingId=3097145167'},
#    {'Name': 'Data Scientist (Python/R) - People Analytics - USDC',
#     'Company': ' Deloitte  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '$97k-$133k',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=400784&s=58&guid=0000016af18f6227a452f3813d2595cc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f5edeb13&cb=1558830867449&jobListingId=3106953665'},
#    {'Name': 'Data Scientist',
#     'Company': ' KEYENCE CORPORATION  ',
#     'State': 'OH',
#     'City': 'Blue Ash',
#     'Salary': '$73k-$105k',
#     'Location': 'Blue Ash, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=352789&s=58&guid=0000016af18f6227a452f3813d2595cc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2e2a5616&cb=1558830867451&jobListingId=3179206551'},
#    {'Name': 'Data Scientist',
#     'Company': ' Vantiv  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '$87k-$124k',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=447365&s=58&guid=0000016af18f6227a452f3813d2595cc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_20b0c698&cb=1558830867452&jobListingId=3217114013'},
#    {'Name': 'Data Scientist',
#     'Company': ' Pozent  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=454816&s=58&guid=0000016af18f6227a452f3813d2595cc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ee011c1c&cb=1558830867453&jobListingId=3177509982'},
#    {'Name': 'Data Scientist',
#     'Company': ' Tata Consulting  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=321738&s=58&guid=0000016af18f6227a452f3813d2595cc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9e0d7c1d&cb=1558830867454&jobListingId=3190845651'},
#    {'Name': 'Data Scientist',
#     'Company': ' IDC Technologies  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '$67k-$95k',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=85058&s=58&guid=0000016af18f6227a452f3813d2595cc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b684f579&cb=1558830867456&jobListingId=3242392737'},
#    {'Name': 'Data Scientist PhD-Marketing Focus',
#     'Company': ' Procter & Gamble  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '$110k-$147k',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=602297&s=58&guid=0000016af18f6227a452f3813d2595cc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_aa6c7dd5&cb=1558830867458&jobListingId=3097145053'},
#    {'Name': 'Data Scientist',
#     'Company': ' Tata Consultancy Services (North America)  ',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '$61k-$86k',
#     'Location': 'Cincinnati, OH',
# ...
#   'Cincinnati': [],
#   'Columbia': [{'Name': 'Statistician III',
#     'Company': ' State of South Carolina  ',
#     'State': 'SC',
#     'City': 'West Columbia',
#     'Salary': '$40k-$62k',
#     'Location': 'West Columbia, SC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=4135&s=58&guid=0000016af190c2828a54f1b5434ecd35&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c69ded54&cb=1558830957674&jobListingId=3243171727'},
#    {'Name': 'Statistician II',
#     'Company': ' State of South Carolina  ',
#     'State': 'SC',
#     'City': 'West Columbia',
#     'Salary': '$37k-$56k',
#     'Location': 'West Columbia, SC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=4135&s=58&guid=0000016af190c2828a54f1b5434ecd35&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ca027949&cb=1558830957678&jobListingId=3243871955'}],
#   'Dallas': [],
#   'Denver': [{'Name': 'Economist/Sociologist/Statistician/Demographer',
#     'Company': ' Colorado State  ',
#     'State': 'CO',
#     'City': 'Denver',
#     'Salary': '?',
#     'Location': 'Denver, CO',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=85058&s=58&guid=0000016af190ca6087507d447f69b905&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_79d20c0c&cb=1558830959546&jobListingId=3237764410'}],
#   'Houston': [],
#   'Jacksonville': [{'Name': 'Senior Healthcare Statistician',
#     'Company': '?',
#     'State': 'FL',
#     'City': 'Jacksonville',
#     'Salary': '?',
#     'Location': 'Jacksonville, FL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=447365&s=58&guid=0000016af190d2608114a45cf6d5ddec&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_22c20fc7&cb=1558830961735&jobListingId=3156874695'}],
#   'Los Angeles': [{'Name': 'Principal Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=316937&s=149&guid=0000016af190d6bfa4a5790ca63e3851&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c97f74dd&cb=1558830962657&jobListingId=3196766868'},
#    {'Name': 'Senior Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=316937&s=149&guid=0000016af190d6bfa4a5790ca63e3851&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8cea524f&cb=1558830962659&jobListingId=3216349811'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=610217&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_75202f27&cb=1558830962660&jobListingId=3205961317'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=4120&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e6009bda&cb=1558830962663&jobListingId=3217914022'},
#    {'Name': 'Director Statistician, Advanced Modeling',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=610217&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ef358992&cb=1558830962673&jobListingId=3192144822'},
#    {'Name': 'Assistant Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=133078&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_023b0e04&cb=1558830962674&jobListingId=3223686685'},
#    {'Name': 'Data Scientist - Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Glendale',
#     'Salary': '?',
#     'Location': 'Glendale, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=4128&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_509d9c3d&cb=1558830962675&jobListingId=3186430574'},
#    {'Name': 'Senior Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=4120&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_65c8a926&cb=1558830962688&jobListingId=3239702862'}],
#   'Louisville': [],
#   'Miami': [],
#   'Minneapolis': [{'Name': 'Distinguished Statistician (Flexible',
#     'Company': ' Medtronic  ',
#     'State': 'MN',
#     'City': 'Minneapolis',
#     'Salary': '?',
#     'Location': 'Minneapolis, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=400784&s=58&guid=0000016af190e1faa4cc7f0fd342c3a1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_14aa357f&cb=1558830965978&jobListingId=3211697831'},
#    {'Name': 'Senior Statistician',
#     'Company': ' Boston Scientific Corporation  ',
#     'State': 'MN',
#     'City': 'Arden Hills',
#     'Salary': '$73k-$104k',
#     'Location': 'Arden Hills, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=447365&s=58&guid=0000016af190e1faa4cc7f0fd342c3a1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_52bcde0d&cb=1558830965986&jobListingId=3182587801'},
#    {'Name': 'Senior Statistician',
#     'Company': ' Medtronic  ',
#     'State': 'MN',
#     'City': 'Fridley',
#     'Salary': '$71k-$102k',
#     'Location': 'Fridley, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=130&ao=447365&s=58&guid=0000016af190e1faa4cc7f0fd342c3a1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_29af921e&cb=1558830965994&jobListingId=3140687190'}],
#   'Nashville': [],
#   'New York': [{'Name': 'Statistician',
#     'Company': '?',
#     'State': 'NY',
#     'City': 'New York',
#     'Salary': '?',
#     'Location': 'New York, NY',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=129&ao=4120&s=58&guid=0000016af190ebfd9eb71b09ba43d952&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a175bf4d&cb=1558830968332&jobListingId=3228074813'}],
#   'Newport News': [{'Name': '3381 Senior Statistician/Biostatistician – Sr. Scientist',
#     'Company': ' IndraSoft  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$73k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=4121&s=58&guid=0000016af190f07fb4ab09cf48e81b69&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2ca26e42&cb=1558830969326&jobListingId=3244875386'},
#    {'Name': 'Senior Statistician/Biostatistician',
#     'Company': ' Battelle  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$82k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=285581&s=58&guid=0000016af190f07fb4ab09cf48e81b69&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_caa87778&cb=1558830969337&jobListingId=3162719672'}],
#   'Phoenix': [{'Name': 'Soccer Statistician',
#     'Company': '?',
#     'State': 'AZ',
#     'City': 'Phoenix',
#     'Salary': '?',
#     'Location': 'Phoenix, AZ',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=66152&s=58&guid=0000016af190f44faabd7fcad65c3236&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_13342a02&cb=1558830970434&jobListingId=3236495700'}],
#   'San Diego': [{'Name': 'Senior Manager, Biomarker Statistician, Non-Clinical Statistics',
#     'Company': ' Pfizer  ',
#     'State': 'CA',
#     'City': 'La Jolla',
#     'Salary': '$110k-$135k',
#     'Location': 'La Jolla, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=592537&s=149&guid=0000016af190f8c3b3ba4a322ac92174&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f29c961e&cb=1558830971486&jobListingId=3129679898'}],
#   'San Francisco': [],
#   'Seattle': [{'Name': 'Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Bellevue',
#     'Salary': '?',
#     'Location': 'Bellevue, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=499713&s=149&guid=0000016af1910105bf2cf94b5c5b27d8&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fe708ef6&cb=1558830973451&jobListingId=3059239372'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Seattle',
#     'Salary': '?',
#     'Location': 'Seattle, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=447365&s=58&guid=0000016af19101058a849ebb04017096&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ff3ea715&cb=1558830973472&jobListingId=3202115378'},
#    {'Name': 'Principal Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Seattle',
#     'Salary': '?',
#     'Location': 'Seattle, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=321738&s=58&guid=0000016af19101058a849ebb04017096&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5de7bf89&cb=1558830973474&jobListingId=3229466176'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Bellevue',
#     'Salary': '?',
#     'Location': 'Bellevue, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=447365&s=58&guid=0000016af19101058a849ebb04017096&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fae71532&cb=1558830973475&jobListingId=3206074971'}],
#   'Virginia Beach': [{'Name': '3381 Senior Statistician/Biostatistician – Sr. Scientist',
#     'Company': ' IndraSoft  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$73k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=4121&s=58&guid=0000016af191047481f47063621aee71&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_96306a7d&cb=1558830974406&jobListingId=3244875386'},
#    {'Name': 'Senior Statistician/Biostatistician',
#     'Company': ' Battelle  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$82k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=285581&s=58&guid=0000016af191047481f47063621aee71&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5ac7e538&cb=1558830974410&jobListingId=3162719672'}]},
#  'Data Analytics Manager': {'Ann Arbor': [],
#   'Atlanta': [{'Name': 'Data Analytics Manager',
#     'Company': ' Deloitte  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$87k-$121k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=144580&s=58&guid=0000016af1910d55b9f88b2677528e2a&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3f1f4d44&cb=1558830976890&jobListingId=3242318423'}],
#   'Austin': [],
#   'Boston': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'MA',
#     'City': 'Boston',
#     'Salary': '?',
#     'Location': 'Boston, MA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=4120&s=58&guid=0000016af19116889905b555f280ca0d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_238934da&cb=1558830979219&jobListingId=3204763127'}],
#   'Charlotte': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=497839&s=58&guid=0000016af1911b70af9439d6ff0899be&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7478f41b&cb=1558830980430&jobListingId=3188717489'},
#    {'Name': 'Risk Advisory Consulting - Data Analytics Manager',
#     'Company': '?',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=137144&s=58&guid=0000016af1911b70af9439d6ff0899be&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_6f301758&cb=1558830980448&jobListingId=3116743526'}],
#   'Chicago': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '?',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=389273&s=58&guid=0000016af191204584d837406e52d7de&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_05f6bb25&cb=1558830981662&jobListingId=3240590320'}],
#   'Cincinnati': [{'Name': 'IT Data Analytics Manager',
#     'Company': '?',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=602297&s=149&guid=0000016af19124928e0cf9a894dbf307&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9b6b1c44&cb=1558830982779&jobListingId=3097391110'},
#    {'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=133995&s=58&guid=0000016af1912492a43855dcebdc7ead&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_d92f3abc&cb=1558830982784&jobListingId=3144712846'},
#    {'Name': 'Associate Data Analytics Manager',
#     'Company': '?',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=153289&s=58&guid=0000016af1912492a43855dcebdc7ead&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c9d55f42&cb=1558830982785&jobListingId=3196250346'}],
#   'Columbia': [],
#   'Dallas': [{'Name': 'Data Analytics Manager : Sr. Manager Analytics',
#     'Company': ' CVS Health  ',
#     'State': 'TX',
#     'City': 'Irving',
#     'Salary': '$92k-$123k',
#     'Location': 'Irving, TX',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=182759&s=58&guid=0000016af1912e5b8943f334f624f2ae&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fc3939ea&cb=1558830985367&jobListingId=3229632266'}],
#   'Denver': [],
#   'Houston': [],
#   'Jacksonville': [],
#   'Los Angeles': [],
#   'Louisville': [],
#   'Miami': [],
#   'Minneapolis': [{'Name': 'Data Analytics Manager',
#     'Company': ' US Bank  ',
#     'State': 'MN',
#     'City': 'Minneapolis',
#     'Salary': '$80k-$112k',
#     'Location': 'Minneapolis, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=173376&s=58&guid=0000016af1914c3bbe43a0064dc64f95&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f11befa4&cb=1558830992962&jobListingId=3168635264'}],
#   'Nashville': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'TN',
#     'City': 'Nashville',
#     'Salary': '?',
#     'Location': 'Nashville, TN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=4321&s=58&guid=0000016af1915099b0b4ec073e9144fc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_09e7afd3&cb=1558830994077&jobListingId=3217010469'}],
#   'New York': [],
#   'Newport News': [],
#   'Phoenix': [],
#   'San Diego': [],
#   'San Francisco': [],
#   'Seattle': [],
#   'Virginia Beach': []}}

# %%
# count check for job listings
for job in search_job:
    print(job)
    for city in search_city:
        print(city)
        count = 1
        for listing in data[job][city]:
            count+=1
        print(f' Total Listings: {count}')
# Out:
# Data Scientist
# Ann Arbor
#  Total Listings: 17
# Atlanta
#  Total Listings: 21
# Austin
#  Total Listings: 20
# Boston
#  Total Listings: 23
# Charlotte
#  Total Listings: 18
# Chicago
#  Total Listings: 15
# Cincinnati
#  Total Listings: 21
# Columbia
#  Total Listings: 1
# Dallas
#  Total Listings: 23
# Denver
#  Total Listings: 20
# Houston
#  Total Listings: 20
# Jacksonville
#  Total Listings: 22
# Los Angeles
#  Total Listings: 15
# Louisville
#  Total Listings: 8
# Miami
#  Total Listings: 14
# Minneapolis
#  Total Listings: 21
# Nashville
#  Total Listings: 15
# New York
#  Total Listings: 16
# Newport News
#  Total Listings: 7
# Phoenix
#  Total Listings: 20
# San Diego
#  Total Listings: 15
# San Francisco
#  Total Listings: 25
# Seattle
#  Total Listings: 18
# Virginia Beach
#  Total Listings: 12
# Data Engineer
# Ann Arbor
#  Total Listings: 6
# Atlanta
#  Total Listings: 11
# Austin
#  Total Listings: 14
# Boston
#  Total Listings: 11
# Charlotte
#  Total Listings: 13
# Chicago
#  Total Listings: 14
# Cincinnati
#  Total Listings: 6
# Columbia
#  Total Listings: 1
# Dallas
#  Total Listings: 7
# Denver
#  Total Listings: 10
# Houston
#  Total Listings: 13
# Jacksonville
#  Total Listings: 6
# Los Angeles
#  Total Listings: 13
# Louisville
#  Total Listings: 5
# Miami
#  Total Listings: 11
# Minneapolis
#  Total Listings: 11
# Nashville
#  Total Listings: 7
# New York
#  Total Listings: 17
# Newport News
#  Total Listings: 3
# Phoenix
#  Total Listings: 9
# San Diego
#  Total Listings: 8
# San Francisco
#  Total Listings: 22
# Seattle
#  Total Listings: 11
# Virginia Beach
#  Total Listings: 3
# Data Analyst
# Ann Arbor
#  Total Listings: 19
# Atlanta
#  Total Listings: 25
# Austin
#  Total Listings: 26
# Boston
#  Total Listings: 23
# Charlotte
#  Total Listings: 27
# Chicago
#  Total Listings: 24
# Cincinnati
#  Total Listings: 25
# Columbia
#  Total Listings: 8
# Dallas
#  Total Listings: 26
# Denver
#  Total Listings: 25
# Houston
#  Total Listings: 26
# Jacksonville
#  Total Listings: 29
# Los Angeles
#  Total Listings: 28
# Louisville
#  Total Listings: 15
# Miami
#  Total Listings: 24
# Minneapolis
#  Total Listings: 25
# Nashville
#  Total Listings: 27
# New York
#  Total Listings: 25
# Newport News
#  Total Listings: 19
# Phoenix
#  Total Listings: 28
# San Diego
#  Total Listings: 26
# San Francisco
#  Total Listings: 29
# Seattle
#  Total Listings: 25
# Virginia Beach
#  Total Listings: 19
# Statistician
# Ann Arbor
#  Total Listings: 7
# Atlanta
#  Total Listings: 10
# Austin
#  Total Listings: 3
# Boston
#  Total Listings: 5
# Charlotte
#  Total Listings: 2
# Chicago
#  Total Listings: 4
# Cincinnati
#  Total Listings: 1
# Columbia
#  Total Listings: 3
# Dallas
#  Total Listings: 1
# Denver
#  Total Listings: 2
# Houston
#  Total Listings: 1
# Jacksonville
#  Total Listings: 2
# Los Angeles
#  Total Listings: 9
# Louisville
#  Total Listings: 1
# Miami
#  Total Listings: 1
# Minneapolis
#  Total Listings: 4
# Nashville
#  Total Listings: 1
# New York
#  Total Listings: 2
# Newport News
#  Total Listings: 3
# Phoenix
#  Total Listings: 2
# San Diego
#  Total Listings: 2
# San Francisco
#  Total Listings: 1
# Seattle
#  Total Listings: 5
# Virginia Beach
#  Total Listings: 3
# Data Analytics Manager
# Ann Arbor
#  Total Listings: 1
# Atlanta
#  Total Listings: 2
# Austin
#  Total Listings: 1
# Boston
#  Total Listings: 2
# Charlotte
#  Total Listings: 3
# Chicago
#  Total Listings: 2
# Cincinnati
#  Total Listings: 4
# Columbia
#  Total Listings: 1
# Dallas
#  Total Listings: 2
# Denver
#  Total Listings: 1
# Houston
#  Total Listings: 1
# Jacksonville
#  Total Listings: 1
# Los Angeles
#  Total Listings: 1
# Louisville
#  Total Listings: 1
# Miami
#  Total Listings: 1
# Minneapolis
#  Total Listings: 2
# Nashville
#  Total Listings: 2
# New York
#  Total Listings: 1
# Newport News
#  Total Listings: 1
# Phoenix
#  Total Listings: 1
# San Diego
#  Total Listings: 1
# San Francisco
#  Total Listings: 1
# Seattle
#  Total Listings: 1
# Virginia Beach
#  Total Listings: 1

# %%
# data checks
len(data['Data Engineer']['Ann Arbor'])
# Out:
# 5

# %%
len(data['Statistician']['Columbia'])
# Out:
# 2

# %%
data['Data Scientist']['New York'][14]
# Out:
# {'Name': 'Data Scientist - Actimize division',
#  'Company': ' NICE Actimize  ',
#  'State': 'NJ',
#  'City': 'Hoboken',
#  'Salary': '$93k-$127k',
#  'Location': 'Hoboken, NJ',
#  'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=632918&s=58&guid=0000016af18f94b8aafc7c23bbac7256&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_991b013b&cb=1558830880435&jobListingId=3204399642'}

# %%
data['Data Scientist']['Miami'][9]['Url']
# Out:
# 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=447365&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cea83dd9&cb=1558830876997&jobListingId=3193763309'

# %%
count = 0
for listing in data['Data Scientist']['Miami']:
    count+=1
    print(count)
    print(listing)
# Out:
# 1
# {'Name': 'Data Scientist', 'Company': '?', 'State': 'FL', 'City': 'Pembroke Pines', 'Salary': '?', 'Location': 'Pembroke Pines, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=512709&s=149&guid=0000016af18f879e9bc467203171444b&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_f8fbbc32&cb=1558830876980&jobListingId=2855332444'}
# 2
# {'Name': 'Data Scientist', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=85058&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e05c926a&cb=1558830876984&jobListingId=3221382657'}
# 3
# {'Name': 'Data Engineer / Data Scientist / Data Analyst - Remote', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=85058&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_10eb7d5c&cb=1558830876988&jobListingId=3239213743'}
# 4
# {'Name': 'Data Scientist', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=389273&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_ae5fd98d&cb=1558830876989&jobListingId=3205714442'}
# 5
# {'Name': 'Data Scientist- Personalization', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=454816&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_98010920&cb=1558830876990&jobListingId=3208677848'}
# 6
# {'Name': 'Data Scientist', 'Company': '?', 'State': 'FL', 'City': 'Doral', 'Salary': '?', 'Location': 'Doral, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=389273&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_43881959&cb=1558830876992&jobListingId=3232605999'}
# 7
# {'Name': 'Jr. Data Scientist', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=389273&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_34f05b9c&cb=1558830876993&jobListingId=3244749766'}
# 8
# {'Name': 'Lead Data Scientist, R&D', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=447365&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7c1cc92f&cb=1558830876994&jobListingId=3175777411'}
# 9
# {'Name': 'Data Scientist, Optimization', 'Company': '?', 'State': 'FL', 'City': 'Fort Lauderdale', 'Salary': '?', 'Location': 'Fort Lauderdale, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=447365&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_629bd05c&cb=1558830876995&jobListingId=3167075914'}
# 10
# {'Name': 'Director, Machine Learning, Data Scientist', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=447365&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_cea83dd9&cb=1558830876997&jobListingId=3193763309'}
# 11
# {'Name': 'Sr. Data Scientist', 'Company': '?', 'State': 'FL', 'City': 'Miami', 'Salary': '?', 'Location': 'Miami, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=119&ao=447365&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_98ef3d66&cb=1558830876999&jobListingId=3133807487'}
# 12
# {'Name': 'Data Scientist, Behavioral Science', 'Company': '?', 'State': 'FL', 'City': 'Fort Lauderdale', 'Salary': '?', 'Location': 'Fort Lauderdale, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=447365&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_913fce06&cb=1558830877001&jobListingId=3167075912'}
# 13
# {'Name': 'Senior Data Scientist, Lifestream', 'Company': '?', 'State': 'FL', 'City': 'Fort Lauderdale', 'Salary': '?', 'Location': 'Fort Lauderdale, FL', 'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=447365&s=58&guid=0000016af18f879eb97e187c1e2b0440&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8a39c8e5&cb=1558830877005&jobListingId=3167075921'}

# %%
# save to json
with open('glassdoor_data.json', 'w') as fp:
    json.dump(data, fp)

# %%
data['Data Architect']

# %%
# build a geojson from the city list and save it to geojson.json
feature_list = []
geolocator = Nominatim(country_bias='US', user_agent="job_coordinates")

for city in search_city:
    get_coords = geolocator.geocode(city)
    lat = get_coords.latitude
    lon = get_coords.longitude

    feature_list.append({'type': 'Feature',
                         'geometry': {
                             'type': 'Point',
                             'coordinates': [lon, lat]
                         },
                         'properties': {
                             'title': city.title(),
                             "icon": "monument"
                         }})

geojson = {
    'type': 'FeatureCollection',
    'features': feature_list
}

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.7312291, 42.2681569]},
#    'properties': {'title': 'Ann Arbor', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.3901849, 33.7490987]},
#    'properties': {'title': 'Atlanta', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-97.7436995, 30.2711286]},
#    'properties': {'title': 'Austin', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-71.0582912, 42.3602534]},
#    'properties': {'title': 'Boston', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.8431268, 35.2270869]},
#    'properties': {'title': 'Charlotte', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-87.6244212, 41.8755616]},
#    'properties': {'title': 'Chicago', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.5124602, 39.1014537]},
#    'properties': {'title': 'Cincinnati', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-81.0343313, 34.0007493]},
#    'properties': {'title': 'Columbia', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-96.7968559, 32.7762719]},
#    'properties': {'title': 'Dallas', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-104.9848623, 39.7392364]},
#    'properties': {'title': 'Denver', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-95.3676974, 29.7589382]},
#    'properties': {'title': 'Houston', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-81.655651, 30.3321838]},
#    'properties': {'title': 'Jacksonville', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-118.2427666, 34.0536909]},
#    'properties': {'title': 'Los Angeles', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-85.759407, 38.2542376]},
#    'properties': {'title': 'Louisville', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.1936589, 25.7742658]},
#    'properties': {'title': 'Miami', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-93.2654692, 44.9772995]},
#    'properties': {'title': 'Minneapolis', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-86.7743531, 36.1622296]},
#    'properties': {'title': 'Nashville', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-74.0060152, 40.7127281]},
#    'properties': {'title': 'New York', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-76.4321089, 36.9786449]},
#    'properties': {'title': 'Newport News', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-112.0773456, 33.4485866]},
#    'properties': {'title': 'Phoenix', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-117.1627714, 32.7174209]},
#    'properties': {'title': 'San Diego', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.4192363, 37.7792808]},
#    'properties': {'title': 'San Francisco', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]},
#    'properties': {'title': 'Seattle', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-75.9774183, 36.8529841]},
#    'properties': {'title': 'Virginia Beach', 'icon': 'monument'}}]}

# %%
lat
# Out:
# 36.8529841

# %%
# save to geojson
with open('geojson.json','w') as f:
    json.dump(geojson, f)

# %%
# upload data to mongoDB
mongo.db.job_listings.update_one({}, {'$set': data}, upsert=True)
mongo.db.geojson.update_one({}, {'$set': geojson}, upsert=True)

# %%
# download data from mongoDB and load to variable
# data = {}
# geojson = {}
data = mongo.db.job_listings.find_one()
geojson = mongo.db.geojson.find_one()

# %%
data
# Out:
# {'_id': ObjectId('5ce84975a7a4282b050acc17'),
#  'Data Analyst': {'Ann Arbor': [{'Name': 'Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '?',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=66506&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_d922da98&cb=1558830922520&jobListingId=3236353110'},
#    {'Name': 'Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '?',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=155686&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_c2d8d967&cb=1558830922522&jobListingId=3194851208'},
#    {'Name': 'Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '?',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=148364&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_61a449ef&cb=1558830922523&jobListingId=3043022161'},
#    {'Name': 'Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '?',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=389273&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_6b36a578&cb=1558830922524&jobListingId=3234048451'},
#    {'Name': 'Data Analyst, Research',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '?',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=359914&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ab67b43d&cb=1558830922525&jobListingId=2955134501'},
#    {'Name': 'Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Northville',
#     'Salary': '?',
#     'Location': 'Northville, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=9619&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_99686043&cb=1558830922526&jobListingId=3089690889'},
#    {'Name': 'Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Farmington Hills',
#     'Salary': '?',
#     'Location': 'Farmington Hills, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=4120&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_29f540f3&cb=1558830922527&jobListingId=3206646874'},
#    {'Name': 'Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Livonia',
#     'Salary': '?',
#     'Location': 'Livonia, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=4120&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ee487100&cb=1558830922528&jobListingId=3203564496'},
#    {'Name': 'Jr. Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Northville',
#     'Salary': '?',
#     'Location': 'Northville, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=389273&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_45f98fdb&cb=1558830922531&jobListingId=3244459943'},
#    {'Name': 'Junior Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Novi',
#     'Salary': '?',
#     'Location': 'Novi, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=4348&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_9da2c4bb&cb=1558830922533&jobListingId=3145928171'},
#    {'Name': 'Healthcare Data Analyst I',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ypsilanti',
#     'Salary': '?',
#     'Location': 'Ypsilanti, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=37049&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_bdb11098&cb=1558830922538&jobListingId=3202348674'},
#    {'Name': 'Precision Health Genetics Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '?',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=4120&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b479d922&cb=1558830922539&jobListingId=3156760105'},
#    {'Name': 'Clinical Data Analyst - Trinity Health',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Livonia',
#     'Salary': '?',
#     'Location': 'Livonia, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=242900&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8e34a02b&cb=1558830922541&jobListingId=3233305488'},
#    {'Name': 'Advanced Data Analyst or AI Engineer',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Ann Arbor',
#     'Salary': '?',
#     'Location': 'Ann Arbor, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=454816&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a5311c87&cb=1558830922547&jobListingId=3230927645'},
#    {'Name': 'Quality Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Livonia',
#     'Salary': '?',
#     'Location': 'Livonia, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=124&ao=83255&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_292b22de&cb=1558830922549&jobListingId=3240774237'},
#    {'Name': 'Sr. Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Farmington',
#     'Salary': '?',
#     'Location': 'Farmington, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=4120&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_df239ed8&cb=1558830922551&jobListingId=3229371158'},
#    {'Name': 'Data Analyst III',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Novi',
#     'Salary': '?',
#     'Location': 'Novi, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=189299&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f70df6e2&cb=1558830922555&jobListingId=3098444701'},
#    {'Name': 'Sr. Data Analyst',
#     'Company': '?',
#     'State': 'MI',
#     'City': 'Livonia',
#     'Salary': '?',
#     'Location': 'Livonia, MI',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=129&ao=85058&s=58&guid=0000016af19039a3b6bb80e30563654c&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fcbb6f08&cb=1558830922557&jobListingId=3220294870'}],
#   'Atlanta': [{'Name': 'Data Analyst',
#     'Company': ' NAVEX Global  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$44k-$67k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=503007&s=149&guid=0000016af1903d8c8b62184d1e35d51b&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_02240003&cb=1558830923582&jobListingId=3149198698'},
#    {'Name': 'Data Analyst/Wrangler, Keying & Linking',
#     'Company': ' Equifax  ',
#     'State': 'GA',
#     'City': 'Alpharetta',
#     'Salary': '$46k-$70k',
#     'Location': 'Alpharetta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=153304&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_da11b116&cb=1558830923583&jobListingId=3238862606'},
#    {'Name': 'Data Analyst',
#     'Company': ' Indeed Prime  Hot',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '?',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=437615&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e8050d2d&cb=1558830923584&jobListingId=3042963906'},
#    {'Name': 'Data Analyst',
#     'Company': ' Primus Software Corporation  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$67k-$110k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=85058&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f5a9c56e&cb=1558830923586&jobListingId=3221380446'},
#    {'Name': 'Data Analyst',
#     'Company': ' ApTask  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$52k-$86k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=352789&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2001bb7c&cb=1558830923587&jobListingId=3231882422'},
#    {'Name': 'Data Analyst',
#     'Company': ' Digi Safari  ',
#     'State': 'GA',
#     'City': 'Alpharetta',
#     'Salary': '$85k-$100k',
#     'Location': 'Alpharetta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=631466&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_a1967918&cb=1558830923588&jobListingId=3227345596'},
#    {'Name': 'Data Analyst',
#     'Company': ' Charter Global, Inc.  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '?',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=108&ao=454816&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_6120c089&cb=1558830923590&jobListingId=3220205281'},
#    {'Name': 'Item Data Management - Data Analyst',
#     'Company': ' Home Depot  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$40k-$62k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=133182&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_4a82ae04&cb=1558830923591&jobListingId=3235701429'},
#    {'Name': 'Data Analyst',
#     'Company': ' Georgia State Government  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$34k-$52k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=3839&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_846e7396&cb=1558830923592&jobListingId=3218539701'},
#    {'Name': 'Data Analyst',
#     'Company': ' CCC Information  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$52k-$82k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=111&ao=133274&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_b91c1d4e&cb=1558830923593&jobListingId=3236836487'},
#    {'Name': 'Data Analyst, Energy Efficiency',
#     'Company': ' ICF  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$39k-$64k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=112&ao=242900&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_45232087&cb=1558830923594&jobListingId=3205627051'},
#    {'Name': 'People Data Analyst',
#     'Company': ' Norfolk Southern Corp.  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$52k-$86k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=113&ao=252473&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_869e946f&cb=1558830923595&jobListingId=3238822589'},
#    {'Name': 'Data Analyst',
#     'Company': ' North Highland  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$61k-$96k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=114&ao=134023&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_807e82e9&cb=1558830923597&jobListingId=3220440962'},
#    {'Name': 'Data Analyst',
#     'Company': ' CoStar Group  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$49k-$75k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=182759&s=58&guid=0000016af1903d8c919d67a437902ac1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f444afdf&cb=1558830923599&jobListingId=3229632487'},
#    {'Name': 'Data Analyst',
#     'Company': ' Macropace Technologies  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '?',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos

#     'Company': '?',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=85058&s=58&guid=0000016af1904a7893a771131d19c51d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f7cfda78&cb=1558830926923&jobListingId=3233697575'}],
#   'Chicago': [{'Name': 'Data Analyst, Quality Interventions - Reporting (Remote in Illinois)',
#     'Company': ' Molina Healthcare  ',
#     'State': 'IL',
#     'City': 'Oak Brook',
#     'Salary': '$45k-$67k',
#     'Location': 'Oak Brook, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=422069&s=149&guid=0000016af1904e75b0a93be4eacc472b&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_245cf73c&cb=1558830928006&jobListingId=3242760068'},
#    {'Name': 'Data Analyst',
#     'Company': ' Indeed Prime  Hot',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '?',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=437619&s=58&guid=0000016af1904e759c25a3bbabd31f1b&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e69d6628&cb=1558830928007&jobListingId=3042963918'},
#    {'Name': 'Data Analyst',
#     'Company': ' Vivid Seats  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$42k-$66k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=513834&s=58&guid=0000016af1904e759c25a3bbabd31f1b&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f10e2a4a&cb=1558830928008&jobListingId=3217321652'},
#    {'Name': 'Marketing Data Analyst',
#     'Company': ' Syngenta  ',
#     'State': 'IL',
#     'City': 'Downers Grove',
#     'Salary': '$63k-$97k',
#     'Location': 'Downers Grove, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=386912&s=58&guid=0000016af1904e759c25a3bbabd31f1b&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_d88b861f&cb=1558830928009&jobListingId=3204592757'},
#    {'Name': 'Data Analyst - CHI',
#     'Company': ' Daugherty Business Solutions  ',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '$61k-$94k',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=506168&s=58&guid=0000016af1904e759c25a3bbabd31f1b&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_793dfe85&cb=1558830928011&jobListingId=3160772820'},
#    {'Name': 'Market Data Analyst',
# ...
#   'Cincinnati': [],
#   'Columbia': [{'Name': 'Statistician III',
#     'Company': ' State of South Carolina  ',
#     'State': 'SC',
#     'City': 'West Columbia',
#     'Salary': '$40k-$62k',
#     'Location': 'West Columbia, SC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=4135&s=58&guid=0000016af190c2828a54f1b5434ecd35&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c69ded54&cb=1558830957674&jobListingId=3243171727'},
#    {'Name': 'Statistician II',
#     'Company': ' State of South Carolina  ',
#     'State': 'SC',
#     'City': 'West Columbia',
#     'Salary': '$37k-$56k',
#     'Location': 'West Columbia, SC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=4135&s=58&guid=0000016af190c2828a54f1b5434ecd35&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ca027949&cb=1558830957678&jobListingId=3243871955'}],
#   'Dallas': [],
#   'Denver': [{'Name': 'Economist/Sociologist/Statistician/Demographer',
#     'Company': ' Colorado State  ',
#     'State': 'CO',
#     'City': 'Denver',
#     'Salary': '?',
#     'Location': 'Denver, CO',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=126&ao=85058&s=58&guid=0000016af190ca6087507d447f69b905&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_79d20c0c&cb=1558830959546&jobListingId=3237764410'}],
#   'Houston': [],
#   'Jacksonville': [{'Name': 'Senior Healthcare Statistician',
#     'Company': '?',
#     'State': 'FL',
#     'City': 'Jacksonville',
#     'Salary': '?',
#     'Location': 'Jacksonville, FL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=447365&s=58&guid=0000016af190d2608114a45cf6d5ddec&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_22c20fc7&cb=1558830961735&jobListingId=3156874695'}],
#   'Los Angeles': [{'Name': 'Principal Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=316937&s=149&guid=0000016af190d6bfa4a5790ca63e3851&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c97f74dd&cb=1558830962657&jobListingId=3196766868'},
#    {'Name': 'Senior Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=316937&s=149&guid=0000016af190d6bfa4a5790ca63e3851&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_8cea524f&cb=1558830962659&jobListingId=3216349811'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=610217&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_75202f27&cb=1558830962660&jobListingId=3205961317'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=4120&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_e6009bda&cb=1558830962663&jobListingId=3217914022'},
#    {'Name': 'Director Statistician, Advanced Modeling',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=115&ao=610217&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ef358992&cb=1558830962673&jobListingId=3192144822'},
#    {'Name': 'Assistant Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=116&ao=133078&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_023b0e04&cb=1558830962674&jobListingId=3223686685'},
#    {'Name': 'Data Scientist - Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Glendale',
#     'Salary': '?',
#     'Location': 'Glendale, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=4128&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_509d9c3d&cb=1558830962675&jobListingId=3186430574'},
#    {'Name': 'Senior Statistician',
#     'Company': '?',
#     'State': 'CA',
#     'City': 'Los Angeles',
#     'Salary': '?',
#     'Location': 'Los Angeles, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=125&ao=4120&s=58&guid=0000016af190d6bfb4a2d7074ad9a434&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_65c8a926&cb=1558830962688&jobListingId=3239702862'}],
#   'Louisville': [],
#   'Miami': [],
#   'Minneapolis': [{'Name': 'Distinguished Statistician (Flexible',
#     'Company': ' Medtronic  ',
#     'State': 'MN',
#     'City': 'Minneapolis',
#     'Salary': '?',
#     'Location': 'Minneapolis, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=400784&s=58&guid=0000016af190e1faa4cc7f0fd342c3a1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_14aa357f&cb=1558830965978&jobListingId=3211697831'},
#    {'Name': 'Senior Statistician',
#     'Company': ' Boston Scientific Corporation  ',
#     'State': 'MN',
#     'City': 'Arden Hills',
#     'Salary': '$73k-$104k',
#     'Location': 'Arden Hills, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=447365&s=58&guid=0000016af190e1faa4cc7f0fd342c3a1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_52bcde0d&cb=1558830965986&jobListingId=3182587801'},
#    {'Name': 'Senior Statistician',
#     'Company': ' Medtronic  ',
#     'State': 'MN',
#     'City': 'Fridley',
#     'Salary': '$71k-$102k',
#     'Location': 'Fridley, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=130&ao=447365&s=58&guid=0000016af190e1faa4cc7f0fd342c3a1&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_29af921e&cb=1558830965994&jobListingId=3140687190'}],
#   'Nashville': [],
#   'New York': [{'Name': 'Statistician',
#     'Company': '?',
#     'State': 'NY',
#     'City': 'New York',
#     'Salary': '?',
#     'Location': 'New York, NY',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=129&ao=4120&s=58&guid=0000016af190ebfd9eb71b09ba43d952&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_a175bf4d&cb=1558830968332&jobListingId=3228074813'}],
#   'Newport News': [{'Name': '3381 Senior Statistician/Biostatistician – Sr. Scientist',
#     'Company': ' IndraSoft  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$73k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=117&ao=4121&s=58&guid=0000016af190f07fb4ab09cf48e81b69&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_2ca26e42&cb=1558830969326&jobListingId=3244875386'},
#    {'Name': 'Senior Statistician/Biostatistician',
#     'Company': ' Battelle  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$82k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=127&ao=285581&s=58&guid=0000016af190f07fb4ab09cf48e81b69&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_caa87778&cb=1558830969337&jobListingId=3162719672'}],
#   'Phoenix': [{'Name': 'Soccer Statistician',
#     'Company': '?',
#     'State': 'AZ',
#     'City': 'Phoenix',
#     'Salary': '?',
#     'Location': 'Phoenix, AZ',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=106&ao=66152&s=58&guid=0000016af190f44faabd7fcad65c3236&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_13342a02&cb=1558830970434&jobListingId=3236495700'}],
#   'San Diego': [{'Name': 'Senior Manager, Biomarker Statistician, Non-Clinical Statistics',
#     'Company': ' Pfizer  ',
#     'State': 'CA',
#     'City': 'La Jolla',
#     'Salary': '$110k-$135k',
#     'Location': 'La Jolla, CA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=592537&s=149&guid=0000016af190f8c3b3ba4a322ac92174&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f29c961e&cb=1558830971486&jobListingId=3129679898'}],
#   'San Francisco': [],
#   'Seattle': [{'Name': 'Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Bellevue',
#     'Salary': '?',
#     'Location': 'Bellevue, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=499713&s=149&guid=0000016af1910105bf2cf94b5c5b27d8&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fe708ef6&cb=1558830973451&jobListingId=3059239372'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Seattle',
#     'Salary': '?',
#     'Location': 'Seattle, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=120&ao=447365&s=58&guid=0000016af19101058a849ebb04017096&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_ff3ea715&cb=1558830973472&jobListingId=3202115378'},
#    {'Name': 'Principal Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Seattle',
#     'Salary': '?',
#     'Location': 'Seattle, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=321738&s=58&guid=0000016af19101058a849ebb04017096&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5de7bf89&cb=1558830973474&jobListingId=3229466176'},
#    {'Name': 'Statistician',
#     'Company': '?',
#     'State': 'WA',
#     'City': 'Bellevue',
#     'Salary': '?',
#     'Location': 'Bellevue, WA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=123&ao=447365&s=58&guid=0000016af19101058a849ebb04017096&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fae71532&cb=1558830973475&jobListingId=3206074971'}],
#   'Virginia Beach': [{'Name': '3381 Senior Statistician/Biostatistician – Sr. Scientist',
#     'Company': ' IndraSoft  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$73k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=118&ao=4121&s=58&guid=0000016af191047481f47063621aee71&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_96306a7d&cb=1558830974406&jobListingId=3244875386'},
#    {'Name': 'Senior Statistician/Biostatistician',
#     'Company': ' Battelle  ',
#     'State': 'VA',
#     'City': 'Portsmouth',
#     'Salary': '$82k-$102k',
#     'Location': 'Portsmouth, VA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=122&ao=285581&s=58&guid=0000016af191047481f47063621aee71&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_5ac7e538&cb=1558830974410&jobListingId=3162719672'}]},
#  'Data Analytics Manager': {'Ann Arbor': [],
#   'Atlanta': [{'Name': 'Data Analytics Manager',
#     'Company': ' Deloitte  ',
#     'State': 'GA',
#     'City': 'Atlanta',
#     'Salary': '$87k-$121k',
#     'Location': 'Atlanta, GA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=107&ao=144580&s=58&guid=0000016af1910d55b9f88b2677528e2a&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_3f1f4d44&cb=1558830976890&jobListingId=3242318423'}],
#   'Austin': [],
#   'Boston': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'MA',
#     'City': 'Boston',
#     'Salary': '?',
#     'Location': 'Boston, MA',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=128&ao=4120&s=58&guid=0000016af19116889905b555f280ca0d&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_238934da&cb=1558830979219&jobListingId=3204763127'}],
#   'Charlotte': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=497839&s=58&guid=0000016af1911b70af9439d6ff0899be&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_7478f41b&cb=1558830980430&jobListingId=3188717489'},
#    {'Name': 'Risk Advisory Consulting - Data Analytics Manager',
#     'Company': '?',
#     'State': 'NC',
#     'City': 'Charlotte',
#     'Salary': '?',
#     'Location': 'Charlotte, NC',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=121&ao=137144&s=58&guid=0000016af1911b70af9439d6ff0899be&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_6f301758&cb=1558830980448&jobListingId=3116743526'}],
#   'Chicago': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'IL',
#     'City': 'Chicago',
#     'Salary': '?',
#     'Location': 'Chicago, IL',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=110&ao=389273&s=58&guid=0000016af191204584d837406e52d7de&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_05f6bb25&cb=1558830981662&jobListingId=3240590320'}],
#   'Cincinnati': [{'Name': 'IT Data Analytics Manager',
#     'Company': '?',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=602297&s=149&guid=0000016af19124928e0cf9a894dbf307&src=GD_JOB_AD&t=SRFJ&extid=4&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_9b6b1c44&cb=1558830982779&jobListingId=3097391110'},
#    {'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=104&ao=133995&s=58&guid=0000016af1912492a43855dcebdc7ead&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_d92f3abc&cb=1558830982784&jobListingId=3144712846'},
#    {'Name': 'Associate Data Analytics Manager',
#     'Company': '?',
#     'State': 'OH',
#     'City': 'Cincinnati',
#     'Salary': '?',
#     'Location': 'Cincinnati, OH',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=105&ao=153289&s=58&guid=0000016af1912492a43855dcebdc7ead&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_c9d55f42&cb=1558830982785&jobListingId=3196250346'}],
#   'Columbia': [],
#   'Dallas': [{'Name': 'Data Analytics Manager : Sr. Manager Analytics',
#     'Company': ' CVS Health  ',
#     'State': 'TX',
#     'City': 'Irving',
#     'Salary': '$92k-$123k',
#     'Location': 'Irving, TX',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=102&ao=182759&s=58&guid=0000016af1912e5b8943f334f624f2ae&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_fc3939ea&cb=1558830985367&jobListingId=3229632266'}],
#   'Denver': [],
#   'Houston': [],
#   'Jacksonville': [],
#   'Los Angeles': [],
#   'Louisville': [],
#   'Miami': [],
#   'Minneapolis': [{'Name': 'Data Analytics Manager',
#     'Company': ' US Bank  ',
#     'State': 'MN',
#     'City': 'Minneapolis',
#     'Salary': '$80k-$112k',
#     'Location': 'Minneapolis, MN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=109&ao=173376&s=58&guid=0000016af1914c3bbe43a0064dc64f95&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&cs=1_f11befa4&cb=1558830992962&jobListingId=3168635264'}],
#   'Nashville': [{'Name': 'Data Analytics Manager',
#     'Company': '?',
#     'State': 'TN',
#     'City': 'Nashville',
#     'Salary': '?',
#     'Location': 'Nashville, TN',
#     'Url': 'https://www.glassdoor.com/partner/jobListing.htm?pos=103&ao=4321&s=58&guid=0000016af1915099b0b4ec073e9144fc&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&ea=1&cs=1_09e7afd3&cb=1558830994077&jobListingId=3217010469'}],
#   'New York': [],
#   'Newport News': [],
#   'Phoenix': [],
#   'San Diego': [],
#   'San Francisco': [],
#   'Seattle': [],
#   'Virginia Beach': []}}

# %%
geojson
# Out:
# {'_id': ObjectId('5ce84975a7a4282b050acc31'),
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-83.7312291, 42.2681569]},
#    'properties': {'title': 'Ann Arbor', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.3901849, 33.7490987]},
#    'properties': {'title': 'Atlanta', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-97.7436995, 30.2711286]},
#    'properties': {'title': 'Austin', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-71.0582912, 42.3602534]},
#    'properties': {'title': 'Boston', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.8431268, 35.2270869]},
#    'properties': {'title': 'Charlotte', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-87.6244212, 41.8755616]},
#    'properties': {'title': 'Chicago', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.5124602, 39.1014537]},
#    'properties': {'title': 'Cincinnati', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-81.0343313, 34.0007493]},
#    'properties': {'title': 'Columbia', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-96.7968559, 32.7762719]},
#    'properties': {'title': 'Dallas', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-104.9848623, 39.7392364]},
#    'properties': {'title': 'Denver', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-95.3676974, 29.7589382]},
#    'properties': {'title': 'Houston', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-81.655651, 30.3321838]},
#    'properties': {'title': 'Jacksonville', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-118.2427666, 34.0536909]},
#    'properties': {'title': 'Los Angeles', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-85.759407, 38.2542376]},
#    'properties': {'title': 'Louisville', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-80.1936589, 25.7742658]},
#    'properties': {'title': 'Miami', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-93.2654692, 44.9772995]},
#    'properties': {'title': 'Minneapolis', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-86.7743531, 36.1622296]},
#    'properties': {'title': 'Nashville', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-74.0060152, 40.7127281]},
#    'properties': {'title': 'New York', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-76.4321089, 36.9786449]},
#    'properties': {'title': 'Newport News', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-112.0773456, 33.4485866]},
#    'properties': {'title': 'Phoenix', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-117.1627714, 32.7174209]},
#    'properties': {'title': 'San Diego', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.4192363, 37.7792808]},
#    'properties': {'title': 'San Francisco', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]},
#    'properties': {'title': 'Seattle', 'icon': 'monument'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-75.9774183, 36.8529841]},
#    'properties': {'title': 'Virginia Beach', 'icon': 'monument'}}],
#  'type': 'FeatureCollection'}
